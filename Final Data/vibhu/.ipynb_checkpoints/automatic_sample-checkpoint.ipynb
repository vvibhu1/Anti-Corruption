# %%
#libraries we need
#!pip install h2o
#!pip install pydotplus
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import date
pd.options.mode.chained_assignment = None
import h2o
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from scipy.special import expit


from sklearn.model_selection import train_test_split

from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus

# %%
df = pd.read_csv('df_agriculture.csv')

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
pd.DataFrame(df.isna().sum()*100/df.shape[0]).plot.bar(figsize=(20,5))

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
cor_matrix = df.corr().abs()
#print(cor_matrix)

upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
#print(upper_tri)

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)] 
print(to_drop)
# Out:
# ['Corruption Perception Rank']

# %%
df_final = df.drop(to_drop, axis=1)
df_final

# %%
# Out:
#      Country Code  Year Country Name  Corruption Perception Index  \
# 0             AFG  2000  Afghanistan                          NaN
# 1             AFG  2000  Afghanistan                          NaN
# 2             AFG  2000  Afghanistan                          NaN
# 3             AFG  2000  Afghanistan                          NaN
# 4             AFG  2000  Afghanistan                          NaN
# ...           ...   ...          ...                          ...
# 5359          ZMB  2017       Zambia                         37.0
# 5360          ZMB  2018       Zambia                         35.0
# 5361          ZMB  2018       Zambia                         35.0
# 5362          ZMB  2019       Zambia                         34.0
# 5363          ZMB  2019       Zambia                         34.0
#
#               IncomeGroup                  region_USAID    region_WorldBank  \
# 0              Low income  South and Central Asia (SCA)          South Asia
# 1              Low income  South and Central Asia (SCA)          South Asia
# 2              Low income  South and Central Asia (SCA)          South Asia
# 3              Low income  South and Central Asia (SCA)          South Asia
# 4              Low income  South and Central Asia (SCA)          South Asia
# ...                   ...                           ...                 ...
# 5359  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 5360  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 5361  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 5362  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 5363  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
#
#       Rural Population  Access To Electricity, Rural (% Of Rural Population)  \
# 0           16192155.0                                                NaN
# 1           16192155.0                                                NaN
# 2           16192155.0                                                NaN
# 3           16192155.0                                                NaN
# 4           16192155.0                                                NaN
# ...                ...                                                ...
# 5359         9610647.0                                          13.997699
# 5360         9800136.0                                          10.968000
# 5361         9800136.0                                          10.968000
# 5362         9989317.0                                                NaN
# 5363         9989317.0                                                NaN
#
#       Food Production Index (2004-2006 = 100)  \
# 0                                       86.04
# 1                                       86.04
# 2                                       86.04
# 3                                       86.04
# 4                                       86.04
# ...                                       ...
# 5359                                      NaN
# 5360                                      NaN
# 5361                                      NaN
# 5362                                      NaN
# 5363                                      NaN
#
#       Agricultural Land (% Of Land Area)  \
# 0                              57.827099
# 1                              57.827099
# 2                              57.827099
# 3                              57.827099
# 4                              57.827099
# ...                                  ...
# 5359                                 NaN
# 5360                                 NaN
# 5361                                 NaN
# 5362                                 NaN
# 5363                                 NaN
#
#       Fertilizer Consumption (% Of Fertilizer Production)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5359                                                NaN
# 5360                                                NaN
# 5361                                                NaN
# 5362                                                NaN
# 5363                                                NaN
#
# [5364 rows x 12 columns]
