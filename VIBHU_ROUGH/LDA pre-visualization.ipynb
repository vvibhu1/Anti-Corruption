# %%
import pandas as pd
import os

# %%
cd /Users/yanglingxi/Desktop/deloitte
# Out:
# /Users/yanglingxi/Desktop/deloitte

# %%
df = pd.read_csv('USAID_Anticorruption_Projects_Database.csv')
df
# Out:
#      uuid                               region      country  \
# 0       1         South and Central Asia (SCA)  Afghanistan
# 1       2         South and Central Asia (SCA)  Afghanistan
# 2       3         South and Central Asia (SCA)  Afghanistan
# 3       4         South and Central Asia (SCA)  Afghanistan
# 4      30             Europe and Eurasia (E&E)      Albania
# ..    ...                                  ...          ...
# 310   311  Middle East and North Africa (MENA)        Yemen
# 311   312  Middle East and North Africa (MENA)        Yemen
# 312   313  Middle East and North Africa (MENA)        Yemen
# 313   314             Sub-Saharan Africa (SSA)       Zambia
# 314   315             Sub-Saharan Africa (SSA)       Zambia
#
#                                                proj_nm  st_date end_date  \
# 0    Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1    Rule of Law Stabilization Program - Formal Com...     2010     2012
# 2    Afghanistan Rule of Law Stabilization Project ...     2011     2012
# 3                           Political Party Assessment     2012     2012
# 4          Justice Sector Strengthening Project (JuST)     2010     2015
# ..                                                 ...      ...      ...
# 310                Responsive Governance Project (RGP)     2010     2015
# 311   Enhancing Government Effectiveness Project (EGE)     2007     2010
# 312                Basic Health Services Project (BHS)     2006     2010
# 313                     Zambia Threshold Project (ZTP)     2006     2008
# 314                Zambia Institutional Reform Program     2010     2013
#
#          awd_amount    awd_value                             implementer  \
# 0    e) $25 M-$50 M     26642989  Management Systems International (MSI)
# 1    e) $25 M-$50 M     33700000                           TetraTech ARD
# 2     c) $5 M-$10 M     10000000    Checchi and Company Consulting, Inc.
# 3          a) <$1 M          NaN    Checchi and Company Consulting, Inc.
# 4     c) $5 M-$10 M      9012613                               Chemonics
# ..              ...          ...                                     ...
# 310  e) $25 M-$50 M     43000000               Counterpart International
# 311    b) $1 M-$5 M      2939048  Management Systems International (MSI)
# 312  d) $10 M-$25 M  21610314.78                Pathfinder International
# 313  d) $10 M-$25 M     22735000                               Chemonics
# 314    b) $1 M-$5 M      4807018                           TetraTech ARD
#
#                                   sector  ...  \
# 0    Independent Agencies, Civil Society  ...
# 1                            Rule of Law  ...
# 2                            Rule of Law  ...
# 3      Elections and Political Processes  ...
# 4             Rule of Law, Civil Society  ...
# ..                                   ...  ...
# 310           Civil Society, Legislature  ...
# 311                           Governance  ...
# 312               Healthcare, Governance  ...
# 313          Rule of Law, Private Sector  ...
# 314                           Governance  ...
#
#                                              rfp_rftop  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://www.fbo.gov/index?s=opportunity&mode=f...
# ..                                                 ...
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
#
#                                       final_res  \
# 0    http://pdf.usaid.gov/pdf_docs/PA00JP3T.pdf
# 1                                           NaN
# 2    http://pdf.usaid.gov/pdf_docs/PDACY340.pdf
# 3    http://pdf.usaid.gov/pdf_docs/PNADZ833.pdf
# 4                                           NaN
# ..                                          ...
# 310                                         NaN
# 311                                         NaN
# 312  http://pdf.usaid.gov/pdf_docs/PDACW754.pdf
# 313  http://pdf.usaid.gov/pdf_docs/PDACL989.pdf
# 314                                         NaN
#
#                                       mind_eval  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 310  http://pdf.usaid.gov/pdf_docs/pdacu527.pdf
# 311                                         NaN
# 312  http://pdf.usaid.gov/pdf_docs/PDACP460.pdf
# 313                                         NaN
# 314                                         NaN
#
#                                      final_eval audit  \
# 0                                           NaN   NaN
# 1    http://pdf.usaid.gov/pdf_docs/PDACU496.pdf   NaN
# 2    http://pdf.usaid.gov/pdf_docs/PDACW029.pdf   NaN
# 3                                           NaN   NaN
# 4                                           NaN   NaN
# ..                                          ...   ...
# 310                                         NaN   NaN
# 311                                         NaN   NaN
# 312                                         NaN   NaN
# 313                                         NaN   NaN
# 314                                         NaN   NaN
#
#                                     interim_rep  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4    http://pdf.usaid.gov/pdf_docs/PA00HWM1.pdf
# ..                                          ...
# 310                                         NaN
# 311                                         NaN
# 312                                         NaN
# 313                                         NaN
# 314  http://pdf.usaid.gov/pdf_docs/PA00JK9W.pdf
#
#                                              addl_docs  \
# 0    http://www.msiworldwide.com/project/supporting...
# 1                                                  NaN
# 2    http://www.checchiconsulting.com/index.php?opt...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 310                                                NaN
# 311  http://www.msiworldwide.com/project/yemen-fund...
# 312                                                NaN
# 313  http://www.mcc.gov/pages/countries/program/zam...
# 314                                                NaN
#
#                                              addl_info            corruption  \
# 0                                                  NaN       High Corruption
# 1                                                  NaN  Very High Corruption
# 2                                                  NaN  Very High Corruption
# 3                                                  NaN  Very High Corruption
# 4                                                  NaN       High Corruption
# ..                                                 ...                   ...
# 310  http://www.counterpart.org/our-work/projects/r...       High Corruption
# 311       http://msiworldwide.wordpress.com/tag/yemen/       High Corruption
# 312                                                NaN       High Corruption
# 313  http://www.mcc.gov/documents/reports/content-r...       High Corruption
# 314                                                NaN       High Corruption
#
#          stability
# 0         Unstable
# 1    Very Unstable
# 2    Very Unstable
# 3    Very Unstable
# 4         Unstable
# ..             ...
# 310  Very Unstable
# 311  Very Unstable
# 312  Very Unstable
# 313       Unstable
# 314       Unstable
#
# [315 rows x 24 columns]

# %%
df = df.drop(columns=['uuid'], axis=1)
df
# Out:
#                                   region      country  \
# 0           South and Central Asia (SCA)  Afghanistan
# 1           South and Central Asia (SCA)  Afghanistan
# 2           South and Central Asia (SCA)  Afghanistan
# 3           South and Central Asia (SCA)  Afghanistan
# 4               Europe and Eurasia (E&E)      Albania
# ..                                   ...          ...
# 310  Middle East and North Africa (MENA)        Yemen
# 311  Middle East and North Africa (MENA)        Yemen
# 312  Middle East and North Africa (MENA)        Yemen
# 313             Sub-Saharan Africa (SSA)       Zambia
# 314             Sub-Saharan Africa (SSA)       Zambia
#
#                                                proj_nm  st_date end_date  \
# 0    Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1    Rule of Law Stabilization Program - Formal Com...     2010     2012
# 2    Afghanistan Rule of Law Stabilization Project ...     2011     2012
# 3                           Political Party Assessment     2012     2012
# 4          Justice Sector Strengthening Project (JuST)     2010     2015
# ..                                                 ...      ...      ...
# 310                Responsive Governance Project (RGP)     2010     2015
# 311   Enhancing Government Effectiveness Project (EGE)     2007     2010
# 312                Basic Health Services Project (BHS)     2006     2010
# 313                     Zambia Threshold Project (ZTP)     2006     2008
# 314                Zambia Institutional Reform Program     2010     2013
#
#          awd_amount    awd_value                             implementer  \
# 0    e) $25 M-$50 M     26642989  Management Systems International (MSI)
# 1    e) $25 M-$50 M     33700000                           TetraTech ARD
# 2     c) $5 M-$10 M     10000000    Checchi and Company Consulting, Inc.
# 3          a) <$1 M          NaN    Checchi and Company Consulting, Inc.
# 4     c) $5 M-$10 M      9012613                               Chemonics
# ..              ...          ...                                     ...
# 310  e) $25 M-$50 M     43000000               Counterpart International
# 311    b) $1 M-$5 M      2939048  Management Systems International (MSI)
# 312  d) $10 M-$25 M  21610314.78                Pathfinder International
# 313  d) $10 M-$25 M     22735000                               Chemonics
# 314    b) $1 M-$5 M      4807018                           TetraTech ARD
#
#                                   sector  \
# 0    Independent Agencies, Civil Society
# 1                            Rule of Law
# 2                            Rule of Law
# 3      Elections and Political Processes
# 4             Rule of Law, Civil Society
# ..                                   ...
# 310           Civil Society, Legislature
# 311                           Governance
# 312               Healthcare, Governance
# 313          Rule of Law, Private Sector
# 314                           Governance
#
#                                           intervention  ...  \
# 0              Corruption Prevention, Public Awareness  ...
# 1    Court Administration, Professional Legal Educa...  ...
# 2                                    Access to Justice  ...
# 3                                           Assessment  ...
# 4    Legal/Institutional Strengthening/Reform, Cour...  ...
# ..                                                 ...  ...
# 310  Legislative/Institutional Strengthening/Reform...  ...
# 311   Financial Management Systems, Public Information  ...
# 312   Service Delivery, Internal Controls, Procurement  ...
# 313  Trade Reforms, Business Environment, Corruptio...  ...
# 314  Service Delivery, Management Systems, Internal...  ...
#
#                                              rfp_rftop  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://www.fbo.gov/index?s=opportunity&mode=f...
# ..                                                 ...
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
#
#                                       final_res  \
# 0    http://pdf.usaid.gov/pdf_docs/PA00JP3T.pdf
# 1                                           NaN
# 2    http://pdf.usaid.gov/pdf_docs/PDACY340.pdf
# 3    http://pdf.usaid.gov/pdf_docs/PNADZ833.pdf
# 4                                           NaN
# ..                                          ...
# 310                                         NaN
# 311                                         NaN
# 312  http://pdf.usaid.gov/pdf_docs/PDACW754.pdf
# 313  http://pdf.usaid.gov/pdf_docs/PDACL989.pdf
# 314                                         NaN
#
#                                       mind_eval  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 310  http://pdf.usaid.gov/pdf_docs/pdacu527.pdf
# 311                                         NaN
# 312  http://pdf.usaid.gov/pdf_docs/PDACP460.pdf
# 313                                         NaN
# 314                                         NaN
#
#                                      final_eval audit  \
# 0                                           NaN   NaN
# 1    http://pdf.usaid.gov/pdf_docs/PDACU496.pdf   NaN
# 2    http://pdf.usaid.gov/pdf_docs/PDACW029.pdf   NaN
# 3                                           NaN   NaN
# 4                                           NaN   NaN
# ..                                          ...   ...
# 310                                         NaN   NaN
# 311                                         NaN   NaN
# 312                                         NaN   NaN
# 313                                         NaN   NaN
# 314                                         NaN   NaN
#
#                                     interim_rep  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4    http://pdf.usaid.gov/pdf_docs/PA00HWM1.pdf
# ..                                          ...
# 310                                         NaN
# 311                                         NaN
# 312                                         NaN
# 313                                         NaN
# 314  http://pdf.usaid.gov/pdf_docs/PA00JK9W.pdf
#
#                                              addl_docs  \
# 0    http://www.msiworldwide.com/project/supporting...
# 1                                                  NaN
# 2    http://www.checchiconsulting.com/index.php?opt...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 310                                                NaN
# 311  http://www.msiworldwide.com/project/yemen-fund...
# 312                                                NaN
# 313  http://www.mcc.gov/pages/countries/program/zam...
# 314                                                NaN
#
#                                              addl_info            corruption  \
# 0                                                  NaN       High Corruption
# 1                                                  NaN  Very High Corruption
# 2                                                  NaN  Very High Corruption
# 3                                                  NaN  Very High Corruption
# 4                                                  NaN       High Corruption
# ..                                                 ...                   ...
# 310  http://www.counterpart.org/our-work/projects/r...       High Corruption
# 311       http://msiworldwide.wordpress.com/tag/yemen/       High Corruption
# 312                                                NaN       High Corruption
# 313  http://www.mcc.gov/documents/reports/content-r...       High Corruption
# 314                                                NaN       High Corruption
#
#          stability
# 0         Unstable
# 1    Very Unstable
# 2    Very Unstable
# 3    Very Unstable
# 4         Unstable
# ..             ...
# 310  Very Unstable
# 311  Very Unstable
# 312  Very Unstable
# 313       Unstable
# 314       Unstable
#
# [315 rows x 23 columns]

# %%
import re

# %%
# Remove punctuation
df['proj_desc'] = df['proj_desc'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
df['proj_desc'] = df['proj_desc'].map(lambda x: x.lower())
# Print out the first rows of papers
df['proj_desc'].head()
# Out:
# 0    the five components of this program seek to ta...
# 1    the overall goal of the program was to support...
# 2    the project focused on strengthening and impro...
# 3    the political party assessment team aimed to r...
# 4    the justice sector strengthening project (just...
# Name: proj_desc, dtype: object

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# a visual representation of most common words

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ','.join(list(df['proj_desc'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1A19BB6210>

# %% [markdown]
# ## Visualise the 10 most common words

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(df['proj_desc'])
# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# /Users/yanglingxi/opt/anaconda3/envs/py37/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below
number_topics = 10
number_words = 5
# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)
# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# legal project rights law judicial
#
# Topic #1:
# project program public government transparency
#
# Topic #2:
# team indonesia liberia reform democratic
#
# Topic #3:
# local program capacity improve government
#
# Topic #4:
# local government project support governance
#
# Topic #5:
# corruption justice capacity project public
#
# Topic #6:
# project government judicial corruption aimed
#
# Topic #7:
# governance corruption local project program
#
# Topic #8:
# project improve government public financial
#
# Topic #9:
# health project land government improve
