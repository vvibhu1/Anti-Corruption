# %%
import pandas as pd
df = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/final.csv')

# %%
df.drop_duplicates()
# Out:
#      Country Code  Year Country Name  Corruption Perception Index  \
# 0             AFG  2005  Afghanistan                          NaN
# 28            AFG  2006  Afghanistan                          NaN
# 56            AFG  2007  Afghanistan                         18.0
# 84            AFG  2008  Afghanistan                         15.0
# 112           AFG  2009  Afghanistan                         13.0
# ...           ...   ...          ...                          ...
# 4014          ZMB  2015       Zambia                         38.0
# 4016          ZMB  2016       Zambia                         38.0
# 4018          ZMB  2017       Zambia                         37.0
# 4020          ZMB  2018       Zambia                         35.0
# 4022          ZMB  2019       Zambia                         34.0
#
#               IncomeGroup                  region_USAID    region_WorldBank  \
# 0              Low income  South and Central Asia (SCA)          South Asia
# ...

# %%
final = df

# %%
final.to_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/DD/final.csv')
