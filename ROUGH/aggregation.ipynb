# %%
import pandas as pd
df = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Final datasets/World_Bank_development_indicators/before_30percentile_usaid_wb_cpi.csv')

# %%
df
# Out:
#     Country Code  Year Country Name  Corruption Perception Index  \
# 0            AFG  2005  Afghanistan                          NaN
# 1            AFG  2006  Afghanistan                          NaN
# 2            AFG  2007  Afghanistan                         18.0
# 3            AFG  2008  Afghanistan                         15.0
# 4            AFG  2009  Afghanistan                         13.0
# ..           ...   ...          ...                          ...
# 926          ZMB  2015       Zambia                         38.0
# 927          ZMB  2016       Zambia                         38.0
# 928          ZMB  2017       Zambia                         37.0
# 929          ZMB  2018       Zambia                         35.0
# 930          ZMB  2019       Zambia                         34.0
#
#              IncomeGroup                  region_USAID    region_WorldBank  \
# 0             Low income  South and Central Asia (SCA)          South Asia
# 1             Low income  South and Central Asia (SCA)          South Asia
# 2             Low income  South and Central Asia (SCA)          South Asia
# 3             Low income  South and Central Asia (SCA)          South Asia
# 4             Low income  South and Central Asia (SCA)          South Asia
# ..                   ...                           ...                 ...
# 926  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 927  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 928  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 929  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
# 930  Lower middle income      Sub-Saharan Africa (SSA)  Sub-Saharan Africa
#
#      Access To Electricity, Rural (% Of Rural Population)  \
# 0                                             8.020724
# 1                                            13.168446
# 2                                            19.868266
# 3                                            27.954251
# 4                                            33.378738
# ..                                                 ...
# 926                                           4.697572
# 927                                           9.305717
# 928                                          13.997699
# 929                                          10.968000
# 930                                          13.775150
#
#      Food Production Index (2004-2006 = 100)  \
# 0                                  106.32000
# 1                                   97.63000
# 2                                  108.92000
# 3                                  100.53000
# 4                                  116.85000
# ..                                       ...
# 926                                180.40000
# 927                                179.77000
# 928                                171.55394
# 929                                156.42136
# 930                                153.82510
#
#      Agricultural Land (% Of Land Area)  ...  \
# 0                             58.067580  ...
# 1                             58.067580  ...
# 2                             58.067580  ...
# 3                             58.067580  ...
# 4                             58.067580  ...
# ..                                  ...  ...
# 926                           32.063923  ...
# 927                           32.063923  ...
# 928                           32.476466  ...
# 929                           33.127447  ...
# 930                           34.782422  ...
#
#      Population Ages 0-14 (% Of Total Population)  \
# 0                                       47.859641
# 1                                       47.989742
# 2                                       48.126233
# 3                                       48.227151
# 4                                       48.250411
# ..                                            ...
# 926                                     46.184516
# 927                                     45.838325
# 928                                     45.411369
# 929                                     44.936141
# 930                                     44.462509
#
#      Access To Clean Fuels And Technologies For Cooking (% Of Population)  \
# 0                                             13.49000
# 1                                             14.81000
# 2                                             15.99000
# 3                                             17.44000
# 4                                             18.84000
# ..                                                 ...
# 926                                           16.31000
# 927                                           16.43000
# 928                                           16.75112
# 929                                           16.58418
# 930                                           17.74318
#
#      People Using At Least Basic Drinking Water Services, Rural (% Of Rural Population)  \
# 0                                            29.542131
# 1                                            31.522881
# 2                                            33.732741
# 3                                            35.969691
# 4                                            38.233731
# ..                                                 ...
# 926                                          40.588167
# 927                                          41.176027
# 928                                          41.952058
# 929                                          44.134510
# 930                                          45.556623
#
#      People Using At Least Basic Sanitation Services, Rural (% Of Rural Population)  \
# 0                                            25.576650
# 1                                            26.521870
# 2                                            27.476086
# 3                                            28.430922
# 4                                            29.386377
# ..                                                 ...
# 926                                          18.141116
# 927                                          18.603971
# 928                                          18.932012
# 929                                          18.919180
# 930                                          18.179606
#
#      Labor Force Participation Rate, Total (% Of Total Population Ages 15-64) (Modeled Ilo Estimate)  \
# 0                                            49.824001
# 1                                            49.594002
# 2                                            49.344002
# 3                                            49.104000
# 4                                            48.910999
# ..                                                 ...
# 926                                          75.802002
# 927                                          75.675003
# 928                                          75.505997
# 929                                          75.313004
# 930                                          75.259003
#
#      Unemployment, Total (% Of Total Labor Force) (Modeled Ilo Estimate)  \
# 0                                               11.429
# 1                                               11.224
# 2                                               11.046
# 3                                               10.985
# 4                                               11.387
# ..                                                 ...
# 926                                             10.105
# 927                                             10.882
# 928                                             11.626
# 929                                             11.500
# 930                                             11.425
#
#      Gdp Per Person Employed (Constant 2017 Ppp $)  \
# 0                                      6148.205597
# 1                                      6318.510106
# 2                                      7056.174167
# 3                                      7213.894886
# 4                                      8627.693985
# ..                                             ...
# 926                                    9469.614628
# 927                                    9574.589725
# 928                                    9648.782217
# 929                                    9676.891123
# 930                                    9479.540064
#
#      Wage And Salaried Workers, Total (% Of Total Employment) (Modeled Ilo Estimate)  \
# 0                                             8.572000
# 1                                             8.647000
# 2                                             8.852000
# 3                                             8.920000
# 4                                             9.906000
# ..                                                 ...
# 926                                          21.038000
# 927                                          21.202000
# 928                                          21.349001
# 929                                          21.507000
# 930                                          21.563000
#
#      Import Volume Index (2000 = 100)  Trade (% Of Gdp)
# 0                          177.942284         79.507150
# 1                          186.504014         60.052205
# 2                          187.697479         55.393618
# 3                          161.947234         60.849345
# 4                          199.383936         49.663426
# ..                                ...               ...
# 926                        578.340085         84.315572
# 927                        556.788892         73.958535
# 928                        567.892902         71.585759
# 929                        626.417589         72.966216
# 930                        344.359603         70.035035
#
# [931 rows x 69 columns]

# %%
df.columns()
# Out:
# Index(['Country Code', 'Year', 'Country Name', 'Corruption Perception Index',
#        'IncomeGroup', 'region_USAID', 'region_WorldBank',
#        'Access To Electricity, Rural (% Of Rural Population)',
#        'Food Production Index (2004-2006 = 100)',
#        'Agricultural Land (% Of Land Area)',
#        'Urban Population (% Of Total Population)',
#        'Population Growth (Annual %)',
#        'Mortality Rate, Under-5 (Per 1,000 Live Births)',
#        'Foreign Direct Investment, Net Inflows (% Of Gdp)',
#        'Price Level Ratio Of Ppp Conversion Factor (Gdp) To Market Exchange Rate',
#        'Net Primary Income (Net Income From Abroad) (Current Us$)',
#        'Gross Savings (% Of Gdp)', 'Gni Growth (Annual %)',
#        'Gross Domestic Savings (% Of Gdp)',
#        'Industry (Including Construction), Value Added (% Of Gdp)',
#        'Imports Of Goods And Services (% Of Gdp)',
#        'Exports Of Goods And Services (% Of Gdp)',
#        'General Government Final Consumption Expenditure (% Of Gdp)',
#        'Inflation, Consumer Prices (Annual %)',
#        'Inflation, Gdp Deflator: Linked Series (Annual %)',
#        'Public Credit Registry Coverage (% Of Adults)',
#        'Private Credit Bureau Coverage (% Of Adults)',
#        'Domestic Credit To Private Sector (% Of Gdp)',
#        'Lending Interest Rate (%)', 'Deposit Interest Rate (%)',
#        'Broad Money Growth (Annual %)', 'Broad Money (% Of Gdp)',
#        'Claims On Private Sector (Annual Growth As % Of Broad Money)',
#        'Claims On Central Government (Annual Growth As % Of Broad Money)',
#        'Total Reserves (% Of Total External Debt)',
#        'Bank Liquid Reserves To Bank Assets Ratio (%)',
#        'Foreign Direct Investment, Net Outflows (% Of Gdp)',
#        'Adolescent Fertility Rate (Births Per 1,000 Women Ages 15-19)',
#        'Prevalence Of Undernourishment (% Of Population)',
#        'Refugee Population By Country Or Territory Of Origin',
#        'Domestic Private Health Expenditure (% Of Current Health Expenditure)',
#        'Domestic General Government Health Expenditure (% Of Gdp)',
#        'Lifetime Risk Of Maternal Death (%)',
#        'Mortality Rate, Neonatal (Per 1,000 Live Births)',
#        'Export Value Index (2000 = 100)', 'Import Value Index (2000 = 100)',
#        'Trade In Services (% Of Gdp)',
#        'Merchandise Exports To Low- And Middle-Income Economies Within Region (% Of Total Merchandise Exports)',
#        'Merchandise Exports To High-Income Economies (% Of Total Merchandise Exports)',
#        'Merchandise Exports To Low- And Middle-Income Economies Outside Region (% Of Total Merchandise Exports)',
#        'Merchandise Imports From Low- And Middle-Income Economies Within Region (% Of Total Merchandise Imports)',
#        'Merchandise Imports From Low- And Middle-Income Economies Outside Region (% Of Total Merchandise Imports)',
#        'Merchandise Imports From High-Income Economies (% Of Total Merchandise Imports)',
#        'Net Barter Terms Of Trade Index (2000 = 100)',
#        'Merchandise Trade (% Of Gdp)',
#        'Total Tax And Contribution Rate (% Of Profit)',
#        'Intentional Homicides (Per 100,000 People)',
#        'Military Expenditure (% Of General Government Expenditure)',
#        'Military Expenditure (% Of Gdp)',
#        'Population Ages 0-14 (% Of Total Population)',
#        'Access To Clean Fuels And Technologies For Cooking (% Of Population)',
#        'People Using At Least Basic Drinking Water Services, Rural (% Of Rural Population)',
#        'People Using At Least Basic Sanitation Services, Rural (% Of Rural Population)',
#        'Labor Force Participation Rate, Total (% Of Total Population Ages 15-64) (Modeled Ilo Estimate)',
#        'Unemployment, Total (% Of Total Labor Force) (Modeled Ilo Estimate)',
#        'Gdp Per Person Employed (Constant 2017 Ppp $)',
#        'Wage And Salaried Workers, Total (% Of Total Employment) (Modeled Ilo Estimate)',
#        'Import Volume Index (2000 = 100)', 'Trade (% Of Gdp)'],
#       dtype='object')
