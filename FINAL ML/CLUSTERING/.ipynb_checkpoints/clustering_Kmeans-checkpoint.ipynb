# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Feature_ENGG/WBI_country_level_features.csv')
hf = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Final datasets/USAID/combined_usaid_country.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name  Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0           0  Afghanistan                               5.677116
# 1           1      Albania                               5.099140
# 2           2       Angola                              12.899514
# 3           3      Armenia                              14.098644
# 4           4   Azerbaijan                              24.210910
#
#    Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                               5.436955
# 1                               3.008076
# 2                               6.922703
# 3                              -1.788671
# 4                              13.323024
#
#    Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                               4.600461
# 1                               2.571634
# 2                               6.444761
# 3                               5.456736
# 4                               2.243221
#
#    Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                               4.601936
# 1                               2.401651
# 2                               2.218368
# 3                               1.093687
# 4                               4.958547
#
#    Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                               4.615721
# 1                               2.381469
# 2                              -0.496080
# 3                               6.580531
# 4                               4.709523
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                           4.558018
# 1                                           1.712014
# 2                                         -39.948226
# 3                                          -2.286083
# 4                                           1.755714
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                          -2.095752
# 1                                           1.552464
# 2                                           7.727869
# 3                                          -0.402710
# 4                                          -0.855201
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                          -2.807691
# 1                                           0.704548
# 2                                          -4.892475
# 3                                           1.497731
# 4                                         -10.997718
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Domestic Private Health Expenditure (% Of Current Health Expenditure)_mean  \
# 0                                          75.752132
# 1                                          47.068026
# 2                                          40.764783
# 3                                          74.995619
# 4                                          80.754805
#
#    Agg_Index_min  Agg_Index_max  Agg_Index_median  Agg_Index_q25  \
# 0     -81.476355      -7.850847        -66.640638     -69.710713
# 1     -59.981628     -20.771572        -46.210480     -53.807621
# 2     -33.562001      73.568802         39.523829      14.102556
# 3     -42.314057      35.810650        -17.727030     -27.679988
# 4    -107.036026     -33.437941        -58.744131     -62.924148
#
#    Agg_Index_q75  Agg_Index_mean          IncomeGroup  \
# 0     -47.119009      -58.145765           Low income
# 1     -35.592073      -44.439404  Upper middle income
# 2      57.019539       31.671816  Lower middle income
# 3     -10.082781      -13.488843  Upper middle income
# 4     -51.792099      -61.175123  Upper middle income
#
#                    region_USAID       region_WorldBank
# 0  South and Central Asia (SCA)             South Asia
# 1      Europe and Eurasia (E&E)  Europe & Central Asia
# 2      Sub-Saharan Africa (SSA)     Sub-Saharan Africa
# 3      Europe and Eurasia (E&E)  Europe & Central Asia
# 4      Europe and Eurasia (E&E)  Europe & Central Asia
#
# [5 rows x 242 columns]

# %%
hf.head()
# Out:
#        country  duration_mean  topic0_mean  topic1_mean  topic2_mean  \
# 0  Afghanistan       3.071429     0.036429     0.037857     0.066071
# 1      Albania       3.750000     0.037500     0.078750     0.053750
# 2       Angola       5.000000     0.030000     0.030000     0.030000
# 3      Armenia       4.250000     0.035000     0.035000     0.035000
# 4   Azerbaijan       2.800000     0.032000     0.032000     0.032000
#
#    topic3_mean  topic4_mean  dominant_topic_4_count  dominant_topic_3_count  \
# 0     0.176429     0.679643                      23                       4
# 1     0.308750     0.523750                       5                       3
# 2     0.030000     0.870000                       1                       0
# 3     0.035000     0.862500                       4                       0
# 4     0.150000     0.752000                       4                       1
#
#    dominant_topic_2_count  ...  awd_amount_median_low  awd_amount_median  \
# 0                       1  ...                      3                  1
# 1                       0  ...                      6                  2
# 2                       0  ...                      0                  1
# 3                       0  ...                      1                  1
# 4                       0  ...                      1                  1
#
#   awd_amount_median_high  awd_amount_high  awd_amount_very_high  \
# 0                      7                7                     5
# 1                      0                0                     0
# 2                      0                0                     0
# 3                      0                0                     0
# 4                      0                0                     0
#
#    corruption_initial  stability_initial  numberofprojects  change_stability  \
# 0     High Corruption           Unstable                28             Worse
# 1     High Corruption           Unstable                 8              Same
# 2     High Corruption           Unstable                 1              Same
# 3     High Corruption           Unstable                 4              Same
# 4     High Corruption           Unstable                 5              Same
#
#    change_corruption
# 0              Worse
# 1               Same
# 2               Same
# 3               Same
# 4               Same
#
# [5 rows x 61 columns]

# %%
df = df.merge(hf,left_on='Country Name',right_on='country',how='left')

# %%
col = df.columns.to_list()

# %%
features = df.drop(['Unnamed: 0','country'],axis = 1)

# %%
features[features.isnull().any(axis=1)]['Country Name']
# Out:
# 35       Laos
# 38      Libya
# 57    Russian
# 59    SENEGAL
# Name: Country Name, dtype: object

# %%
features = features.drop(['Country Name'],axis = 1)

# %%
features.dropna(inplace=True)

# %%
features
# Out:
#     Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0                                5.677116
# 1                                5.099140
# 2                               12.899514
# 3                               14.098644
# 4                               24.210910
# ..                                    ...
# 66                               6.169632
# 67                               4.191391
# 68                               5.919415
# 69                               5.123343
# 70                               8.084064
#
#     Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                                5.436955
# 1                                3.008076
# 2                                6.922703
# 3                               -1.788671
# 4                               13.323024
# ..                                    ...
# 66                              -3.127768
# 67                               5.738994
# 68                               6.628915
# 69                               5.123343
# 70                               5.350326
#
#     Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                                4.600461
# 1                                2.571634
# 2                                6.444761
# 3                                5.456736
# 4                                2.243221
# ..                                    ...
# 66                               1.784881
# 67                               5.409869
# 68                               7.818120
# 69                               5.123343
# 70                               6.713359
#
#     Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                                4.601936
# 1                                2.401651
# 2                                2.218368
# 3                                1.093687
# 4                                4.958547
# ..                                    ...
# 66                              -3.668256
# 67                               6.306509
# 68                               4.167535
# 69                               5.123343
# 70                               4.486793
#
#     Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                                4.615721
# 1                                2.381469
# 2                               -0.496080
# 3                                6.580531
# 4                                4.709523
# ..                                    ...
# 66                               3.597352
# 67                               5.608515
# 68                               2.922891
# 69                               5.123343
# 70                               5.139024
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                            4.558018
# 1                                            1.712014
# 2                                          -39.948226
# 3                                           -2.286083
# 4                                            1.755714
# ..                                                ...
# 66                                          -5.136590
# 67                                           0.932053
# 68                                           0.369228
# 69                                           1.438380
# 70                                         -29.070228
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                           -2.095752
# 1                                            1.552464
# 2                                            7.727869
# 3                                           -0.402710
# 4                                           -0.855201
# ..                                                ...
# 66                                           8.232967
# 67                                           3.956702
# 68                                           1.508832
# 69                                          13.547956
# 70                                           9.899964
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                           -2.807691
# 1                                            0.704548
# 2                                           -4.892475
# 3                                            1.497731
# 4                                          -10.997718
# ..                                                ...
# 66                                           6.120554
# 67                                           2.176640
# 68                                           2.694864
# 69                                          14.834163
# 70                                           5.559029
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2014-2016  \
# 0                                            0.940649
# 1                                           -0.205999
# 2                                           11.930747
# 3                                            4.589541
# 4                                           -3.662210
# ..                                                ...
# 66                                          14.464869
# 67                                           2.258835
# 68                                           0.638049
# 69                                           9.952687
# 70                                           3.022052
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2017-2019  \
# 0                                           -4.160481
# 1                                            0.576152
# 2                                            7.931283
# 3                                            0.835595
# 4                                            1.180285
# ..                                                ...
# 66                                           0.415982
# 67                                          -2.025716
# 68                                          -0.218427
# 69                                           9.952687
# 70                                          13.169666
#
#     ...  awd_amount_median_low  awd_amount_median  awd_amount_median_high  \
# 0   ...                    3.0                1.0                     7.0
# 1   ...                    6.0                2.0                     0.0
# 2   ...                    0.0                1.0                     0.0
# 3   ...                    1.0                1.0                     0.0
# 4   ...                    1.0                1.0                     0.0
# ..  ...                    ...                ...                     ...
# 66  ...                    3.0                2.0                     0.0
# 67  ...                    0.0                2.0                     0.0
# 68  ...                    1.0                4.0                     2.0
# 69  ...                    0.0                1.0                     1.0
# 70  ...                    0.0                1.0                     0.0
#
#     awd_amount_high  awd_amount_very_high  corruption_initial  \
# 0               7.0                   5.0     High Corruption
# 1               0.0                   0.0     High Corruption
# 2               0.0                   0.0     High Corruption
# 3               0.0                   0.0     High Corruption
# 4               0.0                   0.0     High Corruption
# ..              ...                   ...                 ...
# 66              0.0                   0.0     High Corruption
# 67              0.0                   0.0     High Corruption
# 68              2.0                   0.0     High Corruption
# 69              0.0                   0.0     High Corruption
# 70              0.0                   0.0     High Corruption
#
#     stability_initial  numberofprojects  change_stability  change_corruption
# 0            Unstable              28.0             Worse              Worse
# 1            Unstable               8.0              Same               Same
# 2            Unstable               1.0              Same               Same
# 3            Unstable               4.0              Same               Same
# 4            Unstable               5.0              Same               Same
# ..                ...               ...               ...                ...
# 66           Unstable               8.0              Same               Same
# 67           Unstable               2.0              Same               Same
# 68      Very Unstable              10.0              Same               Same
# 69      Very Unstable               3.0              Same               Same
# 70           Unstable               2.0              Same               Same
#
# [67 rows x 300 columns]

# %%
#pip install kneed
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
cat = list(features.select_dtypes(include=['object']).columns)
 
cat.remove('region_USAID')
cat.remove('region_WorldBank')
cat.remove('max_count_topic_categories')
cat.remove('max_count_sector_categories')
cat
# Out:
# ['IncomeGroup',
#  'corruption_initial',
#  'stability_initial',
#  'change_stability',
#  'change_corruption']

# %%
le = preprocessing.LabelEncoder()

for i in cat:
    features[i] = features[i].astype('category')
    features[i] = le.fit_transform(features[i])

# %%
features = pd.get_dummies(features)

# %%
#Standardization scales, or shifts, the values for each numerical feature in your dataset so that the features have a mean of 0 and standard deviation of 1
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
kmeans = KMeans(
    init="random",
    n_clusters=3,
    n_init=10,
    max_iter=300,
    random_state=42)

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
# The lowest SSE value
kmeans.inertia_
# Out:
# 19584.596218488943

# %%
# Final locations of the centroid
kmeans.cluster_centers_
# Out:
# array([[-0.43190317, -0.65024383, -0.28869928, ..., -0.12309149,
#          0.27661061,  0.27661061],
#        [-0.19137459, -0.29857962, -0.32397104, ...,  0.23547937,
#          0.08007921,  0.08007921],
#        [ 0.32310828,  0.49420971,  0.36143305, ..., -0.12309149,
#         -0.1754116 , -0.1754116 ]])

# %%
# The number of iterations required to converge
kmeans.n_iter_
# Out:
# 9

# %%
kmeans.labels_[:15]
# Out:
# array([1, 1, 2, 1, 2, 1, 0, 1, 1, 2, 1, 0, 2, 2, 0], dtype=int32)

# %%
### FINDING THE RIGHT NUMBER OF CLUSTERS
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("ggplot")
plt.plot(range(1, 20), sse)
plt.xticks(range(1, 20))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(
    range(1, 20), sse, curve="convex", direction="decreasing")

n_clusters = kl.elbow

# %%
n_clusters
# Out:
# 11

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 20):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("ggplot")
plt.plot(range(2, 20), silhouette_coefficients)
plt.xticks(range(2, 20))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
kmeans = KMeans(
    init="random",
    n_clusters=n_clusters,
    n_init=10,
    max_iter=300,
    random_state=42
)

kmeans.fit(scaled_features)

silhouette_score(scaled_features, kmeans.labels_)
# Out:
# 0.03991201363511976

# %%
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, adjusted_rand_score
from sklearn.pipeline import Pipeline

# %%
#PCA

pca = PCA(n_components=2, random_state=42)
pca.fit(scaled_features)

#creating a 2-D dataframe
pcadf = pd.DataFrame(
    pca.transform(scaled_features),
    columns=["component_1", "component_2"],
)


#new columns with true labels
pcadf["predicted_cluster"] = kmeans.labels_
pcadf["true_label"] = df['Country Name']

# %%
pcadf
# Out:
#     component_1  component_2  predicted_cluster    true_label
# 0     -2.235176    15.787754                  4   Afghanistan
# 1     -7.707325    -0.364705                  0       Albania
# 2     12.582478    -0.389471                  3        Angola
# 3     -0.808182     0.924318                  4       Armenia
# 4      0.807322     6.958940                  0    Azerbaijan
# ..          ...          ...                ...           ...
# 62     6.373564     0.501642                  7     Sri Lanka
# 63     2.139919     2.640038                  4      Thailand
# 64    -8.578012     0.958862                  0  Turkmenistan
# 65    10.553590     3.613662                  1        Uganda
# 66     5.648553    -1.364576                  3       Ukraine
#
# [67 rows x 4 columns]

# %%
silhouette_score(scaled_features, pcadf['predicted_cluster'])
# Out:
# 0.03991201363511976

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
true_labels = le.fit_transform(pcadf['true_label'])
pcadf["true_label"] = le.inverse_transform(true_labels)
pcadf['predicted_cluster'] = pcadf['predicted_cluster'].astype('category')

# %%
pcadf
# Out:
#     component_1  component_2 predicted_cluster    true_label
# 0     -2.235176    15.787754                 4   Afghanistan
# 1     -7.707325    -0.364705                 0       Albania
# 2     12.582478    -0.389471                 3        Angola
# 3     -0.808182     0.924318                 4       Armenia
# 4      0.807322     6.958940                 0    Azerbaijan
# ..          ...          ...               ...           ...
# 62     6.373564     0.501642                 7     Sri Lanka
# 63     2.139919     2.640038                 4      Thailand
# 64    -8.578012     0.958862                 0  Turkmenistan
# 65    10.553590     3.613662                 1        Uganda
# 66     5.648553    -1.364576                 3       Ukraine
#
# [67 rows x 4 columns]

# %%
pcadf.to_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/FINAL ML/CLUSTERING/pcadf.csv')

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(20, 20))

scat = sns.scatterplot(
    "component_1",
    "component_2",
    s=100,
    data=pcadf,
    hue="predicted_cluster")
scat.set_title(
    "Clustering results"
)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

 
# add annotations one by one with a loop
for line in range(0,pcadf.shape[0]):
     scat.text(pcadf.component_1[line]+0.2, pcadf.component_2[line], pcadf.true_label[line], horizontalalignment='left', size='medium', color='black', weight='semibold',fontsize=9)

plt.show()

# %%
for i in range(10):
    print(pcadf.loc[pcadf['predicted_cluster']==i])
# Out:
#     component_1  component_2 predicted_cluster              true_label
# 1     -7.707325    -0.364705                 0                 Albania
# 4      0.807322     6.958940                 0              Azerbaijan
# 7     -7.816284    -2.040315                 0  Bosnia and Herzegovina
# 8     -6.052652    -1.199718                 0                Bulgaria
# 14    -3.219393    -3.399781                 0      Dominican Republic
# 16    -3.635745    -4.349658                 0                 Ecuador
# 24    -5.843462    -4.506088                 0                  Guyana
# 30    -4.696737     1.490624                 0                  Jordan
# 33    -5.302968     0.209908                 0                  Kosovo
# 35    -6.795619     0.402788                 0                    Laos
# 37    -7.445221     0.914147                 0                 Liberia
# 44    -7.062584    -3.250396                 0                 Moldova
# 45    -5.461527     1.757838                 0                Mongolia
# 51    -3.863844    -1.834392                 0                 Nigeria
# 56    -3.736290    -1.154424                 0             Philippines
# 59    -7.270002     2.974030                 0                 SENEGAL
# 64    -8.578012     0.958862                 0            Turkmenistan
#     component_1  component_2 predicted_cluster true_label
# 49     4.710373     5.401184                 1      Nepal
# 65    10.553590     3.613662                 1     Uganda
#     component_1  component_2 predicted_cluster  true_label
# 36    -0.658457     1.013873                 2     Lebanon
# 46     0.694333    -2.780299                 2  Montenegro
#     component_1  component_2 predicted_cluster  true_label
# 2     12.582478    -0.389471                 3      Angola
# 31     2.891629    -2.784513                 3  Kazakhstan
# 66     5.648553    -1.364576                 3     Ukraine
#     component_1  component_2 predicted_cluster    true_label
# 0     -2.235176    15.787754                 4   Afghanistan
# 3     -0.808182     0.924318                 4       Armenia
# 10    -1.468978     6.790897                 4      Cambodia
# 20    -1.876275    -1.736016                 4       Georgia
# 27    -0.934798     5.004801                 4     Indonesia
# 34     0.377791     1.086128                 4    Kyrgyzstan
# 42    -2.417319     0.189628                 4          Mali
# 47     1.392329     5.859418                 4       Morocco
# 54    -5.307045     5.096306                 4      Paraguay
# 61     0.015143    -0.606970                 4  Sierra Leone
# 63     2.139919     2.640038                 4      Thailand
#     component_1  component_2 predicted_cluster  true_label
# 6     -0.699829    -1.877258                 5     Bolivia
# 25     2.526388    -3.810864                 5       Haiti
# 28     2.027515     2.445502                 5        Iraq
# 40     0.280654    -2.880354                 5  Madagascar
# 43     5.512846     1.182573                 5      Mexico
# 48     1.106192    -5.613544                 5  Mozambique
# 52     0.088139    -0.756716                 5    Pakistan
# 53    -2.564523    -1.310722                 5      Panama
# 55     2.711152    -1.928669                 5        Peru
# 60     3.564299     4.074075                 5      Serbia
#     component_1  component_2 predicted_cluster  true_label
# 15    -8.167987    26.920105                 6  East Timor
#     component_1  component_2 predicted_cluster  true_label
# 5      0.599793     3.915277                 7  Bangladesh
# 9      7.087401    -3.981648                 7     Burundi
# 17     6.648770     3.347239                 7       Egypt
# 19     8.947594    -0.090840                 7    Ethiopia
# 21    10.370384    -1.772228                 7       Ghana
# 23    10.612775    -1.386317                 7      Guinea
# 32     2.263593    -0.775447                 7       Kenya
# 38     0.978798    -0.285009                 7       Libya
# 39     9.614696    -0.681462                 7   Macedonia
# 50     2.770701     3.547274                 7   Nicaragua
# 57     9.574789     3.141201                 7     Russian
# 58     4.123301     0.524204                 7      Rwanda
# 62     6.373564     0.501642                 7   Sri Lanka
#     component_1  component_2 predicted_cluster                    true_label
# 12    14.027013     -6.58424                 8  Democratic Republic of Congo
#     component_1  component_2 predicted_cluster   true_label
# 11    -2.840546    -9.126194                 9     Colombia
# 18    -7.537453   -13.208225                 9  El Salvador
# 22    -2.685326    -6.989263                 9    Guatemala
# 26    -5.056893    -8.198271                 9     Honduras
# 29    -4.639840    -9.484189                 9      Jamaica
# 41    -5.635774    -5.328176                 9       Malawi
