# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Feature_ENGG/WBI_country_level_features.csv')
hf = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Final datasets/USAID/combined_usaid_country.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name  Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0           0  Afghanistan                               5.677116
# 1           1      Albania                               5.099140
# 2           2       Angola                              12.899514
# 3           3      Armenia                              14.098644
# 4           4   Azerbaijan                              24.210910
#
#    Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                               5.436955
# 1                               3.008076
# 2                               6.922703
# 3                              -1.788671
# 4                              13.323024
#
#    Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                               4.600461
# 1                               2.571634
# 2                               6.444761
# 3                               5.456736
# 4                               2.243221
#
#    Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                               4.601936
# 1                               2.401651
# 2                               2.218368
# 3                               1.093687
# 4                               4.958547
#
#    Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                               4.615721
# 1                               2.381469
# 2                              -0.496080
# 3                               6.580531
# 4                               4.709523
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                           4.558018
# 1                                           1.712014
# 2                                         -39.948226
# 3                                          -2.286083
# 4                                           1.755714
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                          -2.095752
# 1                                           1.552464
# 2                                           7.727869
# 3                                          -0.402710
# 4                                          -0.855201
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                          -2.807691
# 1                                           0.704548
# 2                                          -4.892475
# 3                                           1.497731
# 4                                         -10.997718
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Domestic Private Health Expenditure (% Of Current Health Expenditure)_mean  \
# 0                                          75.752132
# 1                                          47.068026
# 2                                          40.764783
# 3                                          74.995619
# 4                                          80.754805
#
#    Agg_Index_min  Agg_Index_max  Agg_Index_median  Agg_Index_q25  \
# 0      32.871811      43.873612         38.175937      34.287943
# 1      20.877058      23.744362         21.992161      21.678448
# 2      29.372782      46.946952         34.295974      32.357318
# 3      23.057783      29.052307         26.212098      25.520548
# 4      26.359437      43.796157         33.850391      29.351774
#
#    Agg_Index_q75  Agg_Index_mean          IncomeGroup  \
# 0      40.558158       37.724774           Low income
# 1      23.005096       22.207973  Upper middle income
# 2      38.525719       35.913270  Lower middle income
# 3      27.319079       26.330111  Upper middle income
# 4      36.146852       33.963581  Upper middle income
#
#                    region_USAID       region_WorldBank
# 0  South and Central Asia (SCA)             South Asia
# 1      Europe and Eurasia (E&E)  Europe & Central Asia
# 2      Sub-Saharan Africa (SSA)     Sub-Saharan Africa
# 3      Europe and Eurasia (E&E)  Europe & Central Asia
# 4      Europe and Eurasia (E&E)  Europe & Central Asia
#
# [5 rows x 242 columns]

# %%
hf.head()
# Out:
#        country  duration_mean  duration_min  duration_max  duration_median  \
# 0  Afghanistan       3.071429             0             7              3.0
# 1      Albania       3.750000             2             5              3.5
# 2       Angola       5.000000             5             5              5.0
# 3      Armenia       4.250000             4             5              4.0
# 4   Azerbaijan       2.800000             1             4              3.0
#
#    topic0_mean  topic0_min  topic0_max  topic0_median  topic1_mean  ...  \
# 0     0.036429        0.03        0.06          0.030     0.037857  ...
# 1     0.037500        0.03        0.05          0.040     0.078750  ...
# 2     0.030000        0.03        0.03          0.030     0.030000  ...
# 3     0.035000        0.03        0.04          0.035     0.035000  ...
# 4     0.032000        0.03        0.04          0.030     0.032000  ...
#
#    awd_amount_median_high  awd_amount_high  awd_amount_very_high  \
# 0                       7                7                     5
# 1                       0                0                     0
# 2                       0                0                     0
# 3                       0                0                     0
# 4                       0                0                     0
#
#    corruption_initial  stability_initial  stability_median  numberofprojects  \
# 0     High Corruption           Unstable     Very Unstable                28
# 1     High Corruption           Unstable          Unstable                 8
# 2     High Corruption           Unstable          Unstable                 1
# 3     High Corruption           Unstable          Unstable                 4
# 4     High Corruption           Unstable          Unstable                 5
#
#       corruption_median  change_stability  change_corruption
# 0  Very High Corruption             Worse              Worse
# 1       High Corruption              Same               Same
# 2       High Corruption              Same               Same
# 3       High Corruption              Same               Same
# 4       High Corruption              Same               Same
#
# [5 rows x 95 columns]

# %%
df = df.merge(hf,left_on='Country Name',right_on='country',how='left')

# %%
col = df.columns.to_list()

# %%
features = df.drop(['Unnamed: 0', 'Country Name','country'],axis = 1)

# %%
cat = list(features.select_dtypes(include=['object']).columns)

# %%
for i in cat:
    features[i] = features[i].astype('category')

# %%
features.dropna(inplace=True)

# %%
features
# Out:
#     Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0                                5.677116
# 1                                5.099140
# 2                               12.899514
# 3                               14.098644
# 4                               24.210910
# ..                                    ...
# 66                               6.169632
# 67                               4.191391
# 68                               5.919415
# 69                               5.123343
# 70                               8.084064
#
#     Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                                5.436955
# 1                                3.008076
# 2                                6.922703
# 3                               -1.788671
# 4                               13.323024
# ..                                    ...
# 66                              -3.127768
# 67                               5.738994
# 68                               6.628915
# 69                               5.123343
# 70                               5.350326
#
#     Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                                4.600461
# 1                                2.571634
# 2                                6.444761
# 3                                5.456736
# 4                                2.243221
# ..                                    ...
# 66                               1.784881
# 67                               5.409869
# 68                               7.818120
# 69                               5.123343
# 70                               6.713359
#
#     Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                                4.601936
# 1                                2.401651
# 2                                2.218368
# 3                                1.093687
# 4                                4.958547
# ..                                    ...
# 66                              -3.668256
# 67                               6.306509
# 68                               4.167535
# 69                               5.123343
# 70                               4.486793
#
#     Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                                4.615721
# 1                                2.381469
# 2                               -0.496080
# 3                                6.580531
# 4                                4.709523
# ..                                    ...
# 66                               3.597352
# 67                               5.608515
# 68                               2.922891
# 69                               5.123343
# 70                               5.139024
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                            4.558018
# 1                                            1.712014
# 2                                          -39.948226
# 3                                           -2.286083
# 4                                            1.755714
# ..                                                ...
# 66                                          -5.136590
# 67                                           0.932053
# 68                                           0.369228
# 69                                           1.438380
# 70                                         -29.070228
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                           -2.095752
# 1                                            1.552464
# 2                                            7.727869
# 3                                           -0.402710
# 4                                           -0.855201
# ..                                                ...
# 66                                           8.232967
# 67                                           3.956702
# 68                                           1.508832
# 69                                          13.547956
# 70                                           9.899964
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                           -2.807691
# 1                                            0.704548
# 2                                           -4.892475
# 3                                            1.497731
# 4                                          -10.997718
# ..                                                ...
# 66                                           6.120554
# 67                                           2.176640
# 68                                           2.694864
# 69                                          14.834163
# 70                                           5.559029
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2014-2016  \
# 0                                            0.940649
# 1                                           -0.205999
# 2                                           11.930747
# 3                                            4.589541
# 4                                           -3.662210
# ..                                                ...
# 66                                          14.464869
# 67                                           2.258835
# 68                                           0.638049
# 69                                           9.952687
# 70                                           3.022052
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2017-2019  \
# 0                                           -4.160481
# 1                                            0.576152
# 2                                            7.931283
# 3                                            0.835595
# 4                                            1.180285
# ..                                                ...
# 66                                           0.415982
# 67                                          -2.025716
# 68                                          -0.218427
# 69                                           9.952687
# 70                                          13.169666
#
#     ...  awd_amount_median_high  awd_amount_high  awd_amount_very_high  \
# 0   ...                     7.0              7.0                   5.0
# 1   ...                     0.0              0.0                   0.0
# 2   ...                     0.0              0.0                   0.0
# 3   ...                     0.0              0.0                   0.0
# 4   ...                     0.0              0.0                   0.0
# ..  ...                     ...              ...                   ...
# 66  ...                     0.0              0.0                   0.0
# 67  ...                     0.0              0.0                   0.0
# 68  ...                     2.0              2.0                   0.0
# 69  ...                     1.0              0.0                   0.0
# 70  ...                     0.0              0.0                   0.0
#
#     corruption_initial  stability_initial  stability_median  numberofprojects  \
# 0      High Corruption           Unstable     Very Unstable              28.0
# 1      High Corruption           Unstable          Unstable               8.0
# 2      High Corruption           Unstable          Unstable               1.0
# 3      High Corruption           Unstable          Unstable               4.0
# 4      High Corruption           Unstable          Unstable               5.0
# ..                 ...                ...               ...               ...
# 66     High Corruption           Unstable          Unstable               8.0
# 67     High Corruption           Unstable          Unstable               2.0
# 68     High Corruption      Very Unstable     Very Unstable              10.0
# 69     High Corruption      Very Unstable     Very Unstable               3.0
# 70     High Corruption           Unstable          Unstable               2.0
#
#        corruption_median  change_stability  change_corruption
# 0   Very High Corruption             Worse              Worse
# 1        High Corruption              Same               Same
# 2        High Corruption              Same               Same
# 3        High Corruption              Same               Same
# 4        High Corruption              Same               Same
# ..                   ...               ...                ...
# 66       High Corruption              Same               Same
# 67       High Corruption              Same               Same
# 68       High Corruption              Same               Same
# 69       High Corruption              Same               Same
# 70       High Corruption              Same               Same
#
# [67 rows x 334 columns]

# %%
#pip install kneed
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
cat.remove('region_USAID')
cat.remove('region_WorldBank')
cat.remove('max_count_topic_categories')
cat.remove('max_count_sector_categories')
cat
# Out:
# ['IncomeGroup',
#  'corruption_initial',
#  'stability_initial',
#  'stability_median',
#  'corruption_median',
#  'change_stability',
#  'change_corruption']

# %%
le = preprocessing.LabelEncoder()

for i in cat:
    features[i] = le.fit_transform(features[i])

# %%
features = pd.get_dummies(features)

# %%
#Standardization scales, or shifts, the values for each numerical feature in your dataset so that the features have a mean of 0 and standard deviation of 1
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
kmeans = KMeans(
    init="random",
    n_clusters=3,
    n_init=10,
    max_iter=300,
    random_state=42)

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
# The lowest SSE value
kmeans.inertia_
# Out:
# 21776.23671613272

# %%
# Final locations of the centroid
kmeans.cluster_centers_
# Out:
# array([[-0.20740294, -0.42201268, -0.3601915 , ...,  0.10599545,
#          0.15104888,  0.15104888],
#        [-0.33179188,  0.14990547, -0.2257267 , ..., -0.12309149,
#         -0.1754116 , -0.1754116 ],
#        [ 0.40787703,  0.5892966 ,  0.60612421, ..., -0.12309149,
#         -0.1754116 , -0.1754116 ]])

# %%
# The number of iterations required to converge
kmeans.n_iter_
# Out:
# 4

# %%
kmeans.labels_[:15]
# Out:
# array([1, 0, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 1, 2, 0], dtype=int32)

# %%
### FINDING THE RIGHT NUMBER OF CLUSTERS
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 20), sse)
plt.xticks(range(1, 20))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(
    range(1, 20), sse, curve="convex", direction="decreasing")

n_clusters = kl.elbow

# %%
n_clusters
# Out:
# 10

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 20):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 20), silhouette_coefficients)
plt.xticks(range(2, 20))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
kmeans = KMeans(
    init="random",
    n_clusters=n_clusters,
    n_init=10,
    max_iter=300,
    random_state=42
)

kmeans.fit(scaled_features)

silhouette_score(scaled_features, kmeans.labels_)
# Out:
# 0.01488254572912248

# %%
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, adjusted_rand_score
from sklearn.pipeline import Pipeline

# %%
#PCA

pca = PCA(n_components=2, random_state=42)
pca.fit(scaled_features)

#creating a 2-D dataframe
pcadf = pd.DataFrame(
    pca.transform(scaled_features),
    columns=["component_1", "component_2"],
)


#new columns with true labels
pcadf["predicted_cluster"] = kmeans.labels_
pcadf["true_label"] = df['Country Name']

# %%
pcadf
# Out:
#     component_1  component_2  predicted_cluster    true_label
# 0     12.479077    22.243800                  1   Afghanistan
# 1     -8.228240     3.448056                  2       Albania
# 2     13.745711    -7.608485                  4        Angola
# 3     -1.681655     0.353450                  2       Armenia
# 4      5.897609     0.183547                  4    Azerbaijan
# ..          ...          ...                ...           ...
# 62     1.574270    -4.064861                  2     Sri Lanka
# 63     2.052942    -4.228078                  2      Thailand
# 64    -9.150557     5.609049                  6  Turkmenistan
# 65     9.830871    -3.500505                  9        Uganda
# 66     3.891609    -5.397985                  4       Ukraine
#
# [67 rows x 4 columns]

# %%
silhouette_score(scaled_features, pcadf['predicted_cluster'])
# Out:
# 0.01488254572912248

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
true_labels = le.fit_transform(pcadf['true_label'])

pcadf["true_label"] = le.inverse_transform(true_labels)
pcadf['predicted_cluster'] = pcadf['predicted_cluster'].astype('category')

# %%
pcadf
# Out:
#     component_1  component_2 predicted_cluster    true_label
# 0     12.479077    22.243800                 1   Afghanistan
# 1     -8.228240     3.448056                 2       Albania
# 2     13.745711    -7.608485                 4        Angola
# 3     -1.681655     0.353450                 2       Armenia
# 4      5.897609     0.183547                 4    Azerbaijan
# ..          ...          ...               ...           ...
# 62     1.574270    -4.064861                 2     Sri Lanka
# 63     2.052942    -4.228078                 2      Thailand
# 64    -9.150557     5.609049                 6  Turkmenistan
# 65     9.830871    -3.500505                 9        Uganda
# 66     3.891609    -5.397985                 4       Ukraine
#
# [67 rows x 4 columns]

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(20, 20))

scat = sns.scatterplot(
    "component_1",
    "component_2",
    s=100,
    data=pcadf,
    hue="predicted_cluster")
scat.set_title(
    "Clustering results"
)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)

 
# add annotations one by one with a loop
for line in range(0,pcadf.shape[0]):
     scat.text(pcadf.component_1[line]+0.2, pcadf.component_2[line], pcadf.true_label[line], horizontalalignment='left', size='medium', color='black', weight='semibold',fontsize=9)

plt.show()

# %%
for i in range(10):
    print(pcadf.loc[pcadf['predicted_cluster']==i])
# Out:
#     component_1  component_2 predicted_cluster true_label
# 36     -3.23184    -8.267483                 0    Lebanon
#    component_1  component_2 predicted_cluster   true_label
# 0    12.479077      22.2438                 1  Afghanistan
#     component_1  component_2 predicted_cluster              true_label
# 1     -8.228240     3.448056                 2                 Albania
# 3     -1.681655     0.353450                 2                 Armenia
# 7     -9.121431     3.381200                 2  Bosnia and Herzegovina
# 10     0.529264    -0.557980                 2                Cambodia
# 20    -4.405971     0.087361                 2                 Georgia
# 27     0.647389     6.148347                 2               Indonesia
# 32    -1.362359    -2.576279                 2                   Kenya
# 33    -5.492581     3.273859                 2                  Kosovo
# 34    -1.231172     1.394358                 2              Kyrgyzstan
# 37    -7.399850     3.671457                 2                 Liberia
# 42    -4.878333     2.273187                 2                    Mali
# 43     6.102184     0.256830                 2                  Mexico
# 47     1.926834     1.503434                 2                 Morocco
# 54    -2.087178     7.347132                 2                Paraguay
# 56    -5.375395     1.335219                 2             Philippines
# 61    -1.813371    -1.117260                 2            Sierra Leone
# 62     1.574270    -4.064861                 2               Sri Lanka
# 63     2.052942    -4.228078                 2                Thailand
#     component_1  component_2 predicted_cluster true_label
# 44    -9.621987     1.053308                 3    Moldova
#     component_1  component_2 predicted_cluster          true_label
# 2     13.745711    -7.608485                 4              Angola
# 4      5.897609     0.183547                 4          Azerbaijan
# 6      1.092400     1.116657                 4             Bolivia
# 11    -5.200228    -0.410003                 4            Colombia
# 14    -4.418715     2.416443                 4  Dominican Republic
# 16    -4.713854     1.191552                 4             Ecuador
# 18    -7.249721     5.661498                 4         El Salvador
# 22    -2.583107     3.599954                 4           Guatemala
# 25     5.282653     2.113512                 4               Haiti
# 26    -4.538295     2.983104                 4            Honduras
# 28     9.688383    11.735203                 4                Iraq
# 29    -7.710996    -1.888937                 4             Jamaica
# 31     1.604829    -2.615266                 4          Kazakhstan
# 40    -1.279698    -1.083228                 4          Madagascar
# 41    -7.127053    -0.370735                 4              Malawi
# 46    -2.459823    -6.442728                 4          Montenegro
# 48     0.016856     0.977422                 4          Mozambique
# 49    10.703035     1.593992                 4               Nepal
# 51    -1.530195    -2.283429                 4             Nigeria
# 52     0.050548     0.805214                 4            Pakistan
# 53     0.380777     2.828152                 4              Panama
# 55     1.472015    -4.085238                 4                Peru
# 60    11.571394     1.252548                 4              Serbia
# 66     3.891609    -5.397985                 4             Ukraine
#     component_1  component_2 predicted_cluster                    true_label
# 12     7.903984   -10.468544                 5  Democratic Republic of Congo
#     component_1  component_2 predicted_cluster    true_label
# 35    -5.840734     4.112616                 6          Laos
# 45    -3.879563     3.940251                 6      Mongolia
# 64    -9.150557     5.609049                 6  Turkmenistan
#     component_1  component_2 predicted_cluster  true_label
# 15    18.443325    16.393321                 7  East Timor
#     component_1  component_2 predicted_cluster true_label
# 8     -6.564045    -0.662417                 8   Bulgaria
# 13    -0.948367    -6.052668                 8   Djibouti
# 24    -6.550334    -0.263450                 8     Guyana
# 30    -4.239210     2.484954                 8     Jordan
# 38    -2.710028    -4.731267                 8      Libya
# 59    -3.510578     2.494689                 8    SENEGAL
#     component_1  component_2 predicted_cluster  true_label
# 5     -0.951793    -0.966664                 9  Bangladesh
# 9      1.956131    -4.188115                 9     Burundi
# 17     4.617295     0.589991                 9       Egypt
# 19     5.417340    -6.581153                 9    Ethiopia
# 21     6.529741    -8.191675                 9       Ghana
# 23     5.336523   -11.286720                 9      Guinea
# 39     3.839871   -10.576390                 9   Macedonia
# 50    -0.822571     0.030942                 9   Nicaragua
# 57     4.528516    -8.654480                 9     Russian
# 58     0.797454    -2.763587                 9      Rwanda
# 65     9.830871    -3.500505                 9      Uganda
