# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Feature_ENGG/WBI_country_level_features.csv')
hf = pd.read_csv('/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/Anti-Corruption/Final datasets/USAID/combined_usaid_country.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name  Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0           0  Afghanistan                               5.677116
# 1           1      Albania                               5.099140
# 2           2       Angola                              12.899514
# 3           3      Armenia                              14.098644
# 4           4   Azerbaijan                              24.210910
#
#    Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                               5.436955
# 1                               3.008076
# 2                               6.922703
# 3                              -1.788671
# 4                              13.323024
#
#    Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                               4.600461
# 1                               2.571634
# 2                               6.444761
# 3                               5.456736
# 4                               2.243221
#
#    Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                               4.601936
# 1                               2.401651
# 2                               2.218368
# 3                               1.093687
# 4                               4.958547
#
#    Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                               4.615721
# 1                               2.381469
# 2                              -0.496080
# 3                               6.580531
# 4                               4.709523
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                           4.558018
# 1                                           1.712014
# 2                                         -39.948226
# 3                                          -2.286083
# 4                                           1.755714
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                          -2.095752
# 1                                           1.552464
# 2                                           7.727869
# 3                                          -0.402710
# 4                                          -0.855201
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                          -2.807691
# 1                                           0.704548
# 2                                          -4.892475
# 3                                           1.497731
# 4                                         -10.997718
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Domestic Private Health Expenditure (% Of Current Health Expenditure)_mean  \
# 0                                          75.752132
# 1                                          47.068026
# 2                                          40.764783
# 3                                          74.995619
# 4                                          80.754805
#
#    Agg_Index_min  Agg_Index_max  Agg_Index_median  Agg_Index_q25  \
# 0     -81.476355      -7.850847        -66.640638     -69.710713
# 1     -59.981628     -20.771572        -46.210480     -53.807621
# 2     -33.562001      73.568802         39.523829      14.102556
# 3     -42.314057      35.810650        -17.727030     -27.679988
# 4    -107.036026     -33.437941        -58.744131     -62.924148
#
#    Agg_Index_q75  Agg_Index_mean          IncomeGroup  \
# 0     -47.119009      -58.145765           Low income
# 1     -35.592073      -44.439404  Upper middle income
# 2      57.019539       31.671816  Lower middle income
# 3     -10.082781      -13.488843  Upper middle income
# 4     -51.792099      -61.175123  Upper middle income
#
#                    region_USAID       region_WorldBank
# 0  South and Central Asia (SCA)             South Asia
# 1      Europe and Eurasia (E&E)  Europe & Central Asia
# 2      Sub-Saharan Africa (SSA)     Sub-Saharan Africa
# 3      Europe and Eurasia (E&E)  Europe & Central Asia
# 4      Europe and Eurasia (E&E)  Europe & Central Asia
#
# [5 rows x 242 columns]

# %%
hf.head()
# Out:
#        country  duration_mean  topic0_mean  topic1_mean  topic2_mean  \
# 0  Afghanistan       3.071429     0.036429     0.037857     0.066071
# 1      Albania       3.750000     0.037500     0.078750     0.053750
# 2       Angola       5.000000     0.030000     0.030000     0.030000
# 3      Armenia       4.250000     0.035000     0.035000     0.035000
# 4   Azerbaijan       2.800000     0.032000     0.032000     0.032000
#
#    topic3_mean  topic4_mean  dominant_topic_4_count  dominant_topic_3_count  \
# 0     0.176429     0.679643                      23                       4
# 1     0.308750     0.523750                       5                       3
# 2     0.030000     0.870000                       1                       0
# 3     0.035000     0.862500                       4                       0
# 4     0.150000     0.752000                       4                       1
#
#    dominant_topic_2_count  ...  awd_amount_median_low  awd_amount_median  \
# 0                       1  ...                      3                  1
# 1                       0  ...                      6                  2
# 2                       0  ...                      0                  1
# 3                       0  ...                      1                  1
# 4                       0  ...                      1                  1
#
#   awd_amount_median_high  awd_amount_high  awd_amount_very_high  \
# 0                      7                7                     5
# 1                      0                0                     0
# 2                      0                0                     0
# 3                      0                0                     0
# 4                      0                0                     0
#
#    corruption_initial  stability_initial  numberofprojects  change_stability  \
# 0     High Corruption           Unstable                28             Worse
# 1     High Corruption           Unstable                 8              Same
# 2     High Corruption           Unstable                 1              Same
# 3     High Corruption           Unstable                 4              Same
# 4     High Corruption           Unstable                 5              Same
#
#    change_corruption
# 0              Worse
# 1               Same
# 2               Same
# 3               Same
# 4               Same
#
# [5 rows x 61 columns]

# %%
df = df.merge(hf,left_on='Country Name',right_on='country',how='left')

# %%
col = df.columns.to_list()

# %%
features = df.drop(['Unnamed: 0','country'],axis = 1)

# %%
features[features.isnull().any(axis=1)]['Country Name']
# Out:
# 35       Laos
# 38      Libya
# 57    Russian
# 59    SENEGAL
# Name: Country Name, dtype: object

# %%
features.dropna(inplace=True)

# %%
features
# Out:
#           Country Name  Gni Growth (Annual %)_MA(3)_2005-2007  \
# 0          Afghanistan                               5.677116
# 1              Albania                               5.099140
# 2               Angola                              12.899514
# 3              Armenia                              14.098644
# 4           Azerbaijan                              24.210910
# ..                 ...                                    ...
# 66             Ukraine                               6.169632
# 67             Vietnam                               4.191391
# 68  West Bank and Gaza                               5.919415
# 69               Yemen                               5.123343
# 70              Zambia                               8.084064
#
#     Gni Growth (Annual %)_MA(3)_2008-2010  \
# 0                                5.436955
# 1                                3.008076
# 2                                6.922703
# 3                               -1.788671
# 4                               13.323024
# ..                                    ...
# 66                              -3.127768
# 67                               5.738994
# 68                               6.628915
# 69                               5.123343
# 70                               5.350326
#
#     Gni Growth (Annual %)_MA(3)_2011-2013  \
# 0                                4.600461
# 1                                2.571634
# 2                                6.444761
# 3                                5.456736
# 4                                2.243221
# ..                                    ...
# 66                               1.784881
# 67                               5.409869
# 68                               7.818120
# 69                               5.123343
# 70                               6.713359
#
#     Gni Growth (Annual %)_MA(3)_2014-2016  \
# 0                                4.601936
# 1                                2.401651
# 2                                2.218368
# 3                                1.093687
# 4                                4.958547
# ..                                    ...
# 66                              -3.668256
# 67                               6.306509
# 68                               4.167535
# 69                               5.123343
# 70                               4.486793
#
#     Gni Growth (Annual %)_MA(3)_2017-2019  \
# 0                                4.615721
# 1                                2.381469
# 2                               -0.496080
# 3                                6.580531
# 4                                4.709523
# ..                                    ...
# 66                               3.597352
# 67                               5.608515
# 68                               2.922891
# 69                               5.123343
# 70                               5.139024
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2005-2007  \
# 0                                            4.558018
# 1                                            1.712014
# 2                                          -39.948226
# 3                                           -2.286083
# 4                                            1.755714
# ..                                                ...
# 66                                          -5.136590
# 67                                           0.932053
# 68                                           0.369228
# 69                                           1.438380
# 70                                         -29.070228
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2008-2010  \
# 0                                           -2.095752
# 1                                            1.552464
# 2                                            7.727869
# 3                                           -0.402710
# 4                                           -0.855201
# ..                                                ...
# 66                                           8.232967
# 67                                           3.956702
# 68                                           1.508832
# 69                                          13.547956
# 70                                           9.899964
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2011-2013  \
# 0                                           -2.807691
# 1                                            0.704548
# 2                                           -4.892475
# 3                                            1.497731
# 4                                          -10.997718
# ..                                                ...
# 66                                           6.120554
# 67                                           2.176640
# 68                                           2.694864
# 69                                          14.834163
# 70                                           5.559029
#
#     Claims On Central Government (Annual Growth As % Of Broad Money)_MA(3)_2014-2016  \
# 0                                            0.940649
# 1                                           -0.205999
# 2                                           11.930747
# 3                                            4.589541
# 4                                           -3.662210
# ..                                                ...
# 66                                          14.464869
# 67                                           2.258835
# 68                                           0.638049
# 69                                           9.952687
# 70                                           3.022052
#
#     ...  awd_amount_median_low  awd_amount_median  awd_amount_median_high  \
# 0   ...                    3.0                1.0                     7.0
# 1   ...                    6.0                2.0                     0.0
# 2   ...                    0.0                1.0                     0.0
# 3   ...                    1.0                1.0                     0.0
# 4   ...                    1.0                1.0                     0.0
# ..  ...                    ...                ...                     ...
# 66  ...                    3.0                2.0                     0.0
# 67  ...                    0.0                2.0                     0.0
# 68  ...                    1.0                4.0                     2.0
# 69  ...                    0.0                1.0                     1.0
# 70  ...                    0.0                1.0                     0.0
#
#     awd_amount_high  awd_amount_very_high  corruption_initial  \
# 0               7.0                   5.0     High Corruption
# 1               0.0                   0.0     High Corruption
# 2               0.0                   0.0     High Corruption
# 3               0.0                   0.0     High Corruption
# 4               0.0                   0.0     High Corruption
# ..              ...                   ...                 ...
# 66              0.0                   0.0     High Corruption
# 67              0.0                   0.0     High Corruption
# 68              2.0                   0.0     High Corruption
# 69              0.0                   0.0     High Corruption
# 70              0.0                   0.0     High Corruption
#
#     stability_initial  numberofprojects  change_stability  change_corruption
# 0            Unstable              28.0             Worse              Worse
# 1            Unstable               8.0              Same               Same
# 2            Unstable               1.0              Same               Same
# 3            Unstable               4.0              Same               Same
# 4            Unstable               5.0              Same               Same
# ..                ...               ...               ...                ...
# 66           Unstable               8.0              Same               Same
# 67           Unstable               2.0              Same               Same
# 68      Very Unstable              10.0              Same               Same
# 69      Very Unstable               3.0              Same               Same
# 70           Unstable               2.0              Same               Same
#
# [67 rows x 301 columns]

# %%
labelList = features['Country Name'].to_list()
features = features.drop(['Country Name'],axis = 1)

# %%
cat = list(features.select_dtypes(include=['object']).columns)
 
cat.remove('region_USAID')
cat.remove('region_WorldBank')
cat.remove('max_count_topic_categories')
cat.remove('max_count_sector_categories')
cat
# Out:
# ['IncomeGroup',
#  'corruption_initial',
#  'stability_initial',
#  'change_stability',
#  'change_corruption']

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

for i in cat:
    features[i] = features[i].astype('category')
    features[i] = le.fit_transform(features[i])

# %%
features = pd.get_dummies(features)

# %%
#Standardization scales, or shifts, the values for each numerical feature in your dataset so that the features have a mean of 0 and standard deviation of 1
scaler = preprocessing.StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(scaled_features, 'complete')

# %%
#We can see that each row of the resulting array has the format [idx1, idx2, dist, sample_count].
linked[:20]
# Out:
# array([[32.        , 61.        , 11.4123485 ,  2.        ],
#        [ 1.        ,  7.        , 11.944122  ,  2.        ],
#        [16.        , 41.        , 12.37225952,  2.        ],
#        [37.        , 56.        , 12.55316056,  2.        ],
#        [19.        , 21.        , 13.02610752,  2.        ],
#        [ 6.        , 40.        , 13.24819675,  2.        ],
#        [ 8.        , 33.        , 13.37144502,  2.        ],
#        [14.        , 22.        , 13.61358822,  2.        ],
#        [24.        , 30.        , 13.62851305,  2.        ],
#        [68.        , 73.        , 14.02506331,  4.        ],
#        [51.        , 53.        , 14.37048946,  2.        ],
#        [34.        , 42.        , 14.66564388,  2.        ],
#        [69.        , 74.        , 15.38654191,  4.        ],
#        [70.        , 76.        , 15.65936893,  6.        ],
#        [35.        , 64.        , 15.79613558,  2.        ],
#        [38.        , 67.        , 16.20213319,  3.        ],
#        [ 5.        , 50.        , 16.23347208,  2.        ],
#        [48.        , 72.        , 16.28158002,  3.        ],
#        [39.        , 71.        , 16.52568112,  3.        ],
#        [75.        , 80.        , 16.84644909,  8.        ]])

# %% [markdown]
# We can observe that until iteration 5 the algorithm only directly merged original samples. We can also observe the monotonic increase of the distance.

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

c, coph_dists = cophenet(linked, pdist(scaled_features))
c

#This (very very briefly) compares (correlates) the actual pairwise distances of all your samples to those implied by the hierarchical clustering. The closer the value is to 1, the better the clustering preserves the original distances
# Out:
# 0.7230207533622778

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10)
plt.axhline(y=16.5, color='r', linestyle='--')

# %% [markdown]
# Summarizing:
#
# - horizontal lines are cluster merges
# - vertical lines tell you which clusters/labels were part of merge forming that new cluster
# - heights of the horizontal lines tell you about the distance that needed to be "bridged" to form the new cluster

# %%
linked
# Out:
# array([[ 32.        ,  61.        ,  11.4123485 ,   2.        ],
#        [  1.        ,   7.        ,  11.944122  ,   2.        ],
#        [ 16.        ,  41.        ,  12.37225952,   2.        ],
#        [ 37.        ,  56.        ,  12.55316056,   2.        ],
#        [ 19.        ,  21.        ,  13.02610752,   2.        ],
#        [  6.        ,  40.        ,  13.24819675,   2.        ],
#        [ 33.        ,  70.        ,  13.25395596,   3.        ],
#        [ 14.        ,  22.        ,  13.61358822,   2.        ],
#        [ 24.        ,  30.        ,  13.62851305,   2.        ],
#        [  8.        ,  68.        ,  13.9562756 ,   3.        ],
#        [ 53.        ,  69.        ,  14.05368387,   3.        ],
#        [ 34.        ,  42.        ,  14.66564388,   2.        ],
#        [ 73.        ,  76.        ,  15.18343207,   6.        ],
#        [ 74.        ,  77.        ,  15.69138855,   5.        ],
#        [ 35.        ,  64.        ,  15.79613558,   2.        ],
#        [  5.        ,  50.        ,  16.23347208,   2.        ],
#        [ 39.        ,  71.        ,  17.01365167,   3.        ],
#        [ 51.        ,  59.        ,  17.02247552,   2.        ],
#        [ 48.        ,  72.        ,  17.10481238,   3.        ],
#        [ 11.        ,  29.        ,  17.14096013,   2.        ],
#        [ 38.        ,  58.        ,  17.28548396,   2.        ],
#        [  3.        ,  20.        ,  17.71357389,   2.        ],
#        [ 10.        ,  63.        ,  17.84640037,   2.        ],
#        [ 80.        ,  86.        ,  18.6136418 ,   7.        ],
#        [ 18.        ,  26.        ,  18.67331237,   2.        ],
#        [ 82.        ,  87.        ,  18.87336422,   4.        ],
#        [ 31.        ,  66.        ,  19.02381109,   2.        ],
#        [ 75.        ,  79.        ,  19.07207202,   8.        ],
#        [ 27.        ,  54.        ,  19.33718347,   2.        ],
#        [ 45.        ,  81.        ,  19.62490402,   3.        ],
#        [ 46.        ,  55.        ,  19.97256976,   2.        ],
#        [ 67.        ,  78.        ,  20.33453209,   4.        ],
#        [ 47.        ,  98.        ,  20.67917008,   5.        ],
#        [ 93.        ,  97.        ,  21.11834426,   4.        ],
#        [ 25.        ,  85.        ,  21.29668013,   4.        ],
#        [  9.        ,  83.        ,  21.71174745,   4.        ],
#        [ 52.        ,  99.        ,  22.0803019 ,   6.        ],
#        [ 84.        ,  94.        ,  22.69956925,  10.        ],
#        [ 17.        ,  62.        ,  22.97043473,   2.        ],
#        [ 44.        ,  88.        ,  23.47376425,   3.        ],
#        [ 96.        , 104.        ,  23.64029226,  13.        ],
#        [ 49.        ,  65.        ,  24.18290694,   2.        ],
#        [100.        , 102.        ,  24.81060933,   8.        ],
#        [ 90.        ,  91.        ,  24.88798539,   9.        ],
#        [ 92.        ,  95.        ,  25.60836142,   6.        ],
#        [103.        , 111.        ,  26.5051381 ,  12.        ],
#        [ 23.        , 105.        ,  27.14540734,   3.        ],
#        [101.        , 110.        ,  27.46635921,  13.        ],
#        [  4.        ,  89.        ,  27.53138894,   3.        ],
#        [108.        , 113.        ,  27.67426833,   5.        ],
#        [  2.        , 109.        ,  28.75300041,   9.        ],
#        [106.        , 107.        ,  29.19990433,  16.        ],
#        [ 43.        , 115.        ,  30.84311548,   4.        ],
#        [ 60.        , 119.        ,  31.42060662,   5.        ],
#        [ 12.        ,  57.        ,  31.59230719,   2.        ],
#        [116.        , 121.        ,  32.69828796,   7.        ],
#        [117.        , 122.        ,  34.35077374,  16.        ],
#        [ 13.        , 120.        ,  34.95724249,   6.        ],
#        [  0.        ,  28.        ,  36.71436285,   2.        ],
#        [112.        , 118.        ,  36.93685838,  28.        ],
#        [124.        , 126.        ,  42.01549642,  34.        ],
#        [ 36.        , 127.        ,  45.3329582 ,  35.        ],
#        [114.        , 128.        ,  47.8688298 ,  48.        ],
#        [125.        , 129.        ,  49.58028341,  50.        ],
#        [123.        , 130.        ,  53.71383073,  66.        ],
#        [ 15.        , 131.        ,  54.30909124,  67.        ]])

# %%
## 66 Merges in tota = n - 1

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms Truncated - 6")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10,truncate_mode='lastp',p=6,show_contracted=True)
plt.axhline(y=16.5, color='r', linestyle='--')

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms Truncated - 14")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10,truncate_mode='lastp',p=14,show_contracted=True)
plt.axhline(y=16.5, color='r', linestyle='--')

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms Truncated - 20")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10,truncate_mode='lastp',p=20,show_contracted=True)
plt.axhline(y=16.5, color='r', linestyle='--')

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms Truncated - 26")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10,truncate_mode='lastp',p=26,show_contracted=True)
plt.axhline(y=16.5, color='r', linestyle='--')

# %%
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
plt.figure(figsize=(20, 14))  
plt.title("Dendrograms Truncated - 32")  
linked = shc.linkage(scaled_features, method='ward')
dend = shc.dendrogram(linked,labels=labelList,leaf_font_size=10,truncate_mode='lastp',p=32,show_contracted=True)
plt.axhline(y=16.5, color='r', linestyle='--')

# %%
## ANNOTATING THE DISTANCES IN THE DENDOGRAM
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
plt.figure(figsize=(20, 14))  

fancy_dendrogram(
    linked,
    truncate_mode='lastp',
    p=52,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,  # useful in small plots so annotations don't overlap
    labels=labelList)
plt.axhline(y=16.5, color='r', linestyle='--')
plt.show()

# %%
## typically interested in a huge jump.

# %%
## CHOOSING THE RIGHT METHOD TO CUT THE LINE 

#INCONSISTENCY METHOD

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.inconsistent.html

# %%
from scipy.cluster.hierarchy import inconsistent

depth = 3
incons = inconsistent(linked, depth)
incons[-10:]
# Out:
# array([[29.97987449,  3.53940145,  6.        ,  1.2349261 ],
#        [32.4069882 ,  2.22738001,  3.        ,  1.14495698],
#        [36.71436285,  0.        ,  1.        ,  0.        ],
#        [26.77780295,  5.05539453,  7.        ,  2.0095475 ],
#        [33.50587439,  5.62479895,  6.        ,  1.51287577],
#        [39.81063887,  4.73185934,  4.        ,  1.16705061],
#        [34.81138486, 11.56001817,  6.        ,  1.12953498],
#        [41.3925587 ,  9.22404765,  5.        ,  0.88764987],
#        [40.52562413,  9.68120747,  7.        ,  1.36224811],
#        [47.98849478,  9.33185651,  4.        ,  0.67731394]])

# %%
last = linked[:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()
k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
print("clusters:", k)
# Out:
# clusters: 7

# %%
depth = 5
incons = inconsistent(linked, depth)
incons[-10:]
# Out:
# array([[25.21558001,  5.34085934, 14.        ,  1.71043518],
#        [28.51975078,  6.52210771,  5.        ,  0.98702628],
#        [36.71436285,  0.        ,  1.        ,  0.        ],
#        [21.6903451 ,  5.18821715, 19.        ,  2.93868064],
#        [26.28556864,  6.8243254 , 18.        ,  2.30497915],
#        [31.00116999,  7.51221336, 12.        ,  1.90779835],
#        [27.55061006, 10.80388992, 17.        ,  1.88063928],
#        [32.41914022, 11.7486908 , 13.        ,  1.46068558],
#        [32.78497048, 10.28138253, 19.        ,  2.03560758],
#        [38.06653557, 10.64308918, 13.        ,  1.5261129 ]])

# %%
last = linked[:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()
k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
print("clusters:", k)
# Out:
# clusters: 7

# %%
#if we want to decide the number of clusters we can say 7

# %% [raw]
# MEAN |  STD | number of links |  inconsistency coefficient,
