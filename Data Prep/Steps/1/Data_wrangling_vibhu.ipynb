# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/vibhuverma/Desktop/CLASSWORK/BUSINESS PRACTICUM/ANALYSIS 1'

# %%
dfi = pd.read_excel("Ind.xlsx")
dfi.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access To Clean Fuels And Technologies For Coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access To Electricity (% Of Population)     EG.ELC.ACCS.ZS   NaN
# 2  Access To Electricity, Rural (% Of Rural Popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access To Electricity, Urban (% Of Urban Popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account Ownership At A Financial Institution O...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011  2012  2013      2014  2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN   NaN   NaN       NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...        NaN   NaN   NaN       NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...        NaN   NaN   NaN       NaN   NaN
# ...

# %%
yr_list = [str(x) for x in range(2000,2020,1)]
df = dfi.melt(id_vars =['Indicator Code','Country Name', 'Indicator Name'], value_vars = yr_list, var_name ='Year', value_name ='Value') 
df.head(20)
# Out:
#               Indicator Code Country Name  \
# 0             EG.CFT.ACCS.ZS   Arab World
# 1             EG.ELC.ACCS.ZS   Arab World
# 2          EG.ELC.ACCS.RU.ZS   Arab World
# 3          EG.ELC.ACCS.UR.ZS   Arab World
# 4             FX.OWN.TOTL.ZS   Arab World
# 5          FX.OWN.TOTL.FE.ZS   Arab World
# 6          FX.OWN.TOTL.MA.ZS   Arab World
# 7          FX.OWN.TOTL.OL.ZS   Arab World
# 8          FX.OWN.TOTL.40.ZS   Arab World
# 9          FX.OWN.TOTL.PL.ZS   Arab World
# 10         FX.OWN.TOTL.60.ZS   Arab World
# 11         FX.OWN.TOTL.SO.ZS   Arab World
# 12         FX.OWN.TOTL.YG.ZS   Arab World
# 13  per_si_allsi.adq_pop_tot   Arab World
# 14     per_allsp.adq_pop_tot   Arab World
# 15  per_sa_allsa.adq_pop_tot   Arab World
# 16  per_lm_alllm.adq_pop_tot   Arab World
# 17               SE.PRM.TENR   Arab World
# 18            SE.PRM.TENR.FE   Arab World
# 19            SE.PRM.TENR.MA   Arab World
#
# ...

# %%
df.shape
# Out:
# (7587360, 5)

# %%
indicator = df[["Indicator Name","Indicator Code"]]

# %%
df.drop(['Indicator Name'], axis = 1) 
df['Year'] = pd.to_numeric(df['Year'])

# %%
df['Country Name'].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
region = ['Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
       'World']

# %%
df_country = df[~df['Country Name'].isin(region)]

# %%
df_region = df[df['Country Name'].isin(region)]

# %%
df_country.head()
# Out:
#           Indicator Code Country Name  \
# 67539     EG.CFT.ACCS.ZS  Afghanistan
# 67540     EG.ELC.ACCS.ZS  Afghanistan
# 67541  EG.ELC.ACCS.RU.ZS  Afghanistan
# 67542  EG.ELC.ACCS.UR.ZS  Afghanistan
# 67543     FX.OWN.TOTL.ZS  Afghanistan
#
#                                           Indicator Name  Year  Value
# 67539  Access To Clean Fuels And Technologies For Coo...  2000    8.8
# 67540            Access To Electricity (% Of Population)  2000    NaN
# 67541  Access To Electricity, Rural (% Of Rural Popul...  2000    NaN
# 67542  Access To Electricity, Urban (% Of Urban Popul...  2000    NaN
# 67543  Account Ownership At A Financial Institution O...  2000    NaN

# %%
df_region.head()
# Out:
#       Indicator Code Country Name  \
# 0     EG.CFT.ACCS.ZS   Arab World
# 1     EG.ELC.ACCS.ZS   Arab World
# 2  EG.ELC.ACCS.RU.ZS   Arab World
# 3  EG.ELC.ACCS.UR.ZS   Arab World
# 4     FX.OWN.TOTL.ZS   Arab World
#
#                                       Indicator Name  Year  Value
# 0  Access To Clean Fuels And Technologies For Coo...  2000    NaN
# 1            Access To Electricity (% Of Population)  2000    NaN
# 2  Access To Electricity, Rural (% Of Rural Popul...  2000    NaN
# 3  Access To Electricity, Urban (% Of Urban Popul...  2000    NaN
# 4  Account Ownership At A Financial Institution O...  2000    NaN

# %%
#df.to_csv('melt_indicators.csv')

# %%
#df_country.to_csv('melt_ind_c.csv')

# %%
#df_region.to_csv('melt_ind_r.csv')
