# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/thuyt/Documents/GitHub/Anti-Corruption/Final datasets/World_Bank_development_indicators/selected30percentile_indicators.csv')

# %%
df.head()
# Out:
#   Country Code Country Name                  Region_USAID  Year IncomeGroup  \
# 0          AFG  Afghanistan  South and Central Asia (SCA)  2007  Low income
# 1          AFG  Afghanistan  South and Central Asia (SCA)  2008  Low income
# 2          AFG  Afghanistan  South and Central Asia (SCA)  2009  Low income
# 3          AFG  Afghanistan  South and Central Asia (SCA)  2010  Low income
# 4          AFG  Afghanistan  South and Central Asia (SCA)  2011  Low income
#
#    Corruption Perception Index  Gni Growth (Annual %)  \
# 0                           18               5.786177
# 1                           15               5.025873
# 2                           13               5.360281
# 3                           14               5.924710
# 4                           15               3.644086
#
#    Intentional Homicides (Per 100,000 People)  \
# 0                                    4.906175
# 1                                    4.105054
# ...

# %%
df2 = df.groupby(['Region_USAID', 'Year']).mean()

# %%
df.columns
# Out:
# Index(['Country Code', 'Country Name', 'Region_USAID', 'Year', 'IncomeGroup',
#        'Corruption Perception Index', 'Gni Growth (Annual %)',
#        'Intentional Homicides (Per 100,000 People)',
#        'Food Production Index (2004-2006 = 100)',
#        'Claims On Central Government (Annual Growth As % Of Broad Money)',
#        'Foreign Direct Investment, Net Inflows (% Of Gdp)',
#        'Import Value Index (2000 = 100)',
#        'Inflation, Consumer Prices (Annual %)',
#        'Claims On Private Sector (Annual Growth As % Of Broad Money)',
#        'Inflation, Gdp Deflator: Linked Series (Annual %)',
#        'Broad Money Growth (Annual %)', 'Import Volume Index (2000 = 100)',
#        'Merchandise Imports From Low- And Middle-Income Economies Outside Region (% Of Total Merchandise Imports)',
#        'Bank Liquid Reserves To Bank Assets Ratio (%)',
#        'Total Tax And Contribution Rate (% Of Profit)',
#        'Exports Of Goods And Services (% Of Gdp)',
# ...

# %%
df2 = df2.reset_index()

# %%
df2.head()
# Out:
#                   Region_USAID  Year  Corruption Perception Index  \
# 0  East Asia and Pacific (EAP)  2007                    26.166667
# 1  East Asia and Pacific (EAP)  2008                    26.500000
# 2  East Asia and Pacific (EAP)  2009                    26.666667
# 3  East Asia and Pacific (EAP)  2010                    27.000000
# 4  East Asia and Pacific (EAP)  2011                    27.833333
#
#    Gni Growth (Annual %)  Intentional Homicides (Per 100,000 People)  \
# 0               7.453816                                    4.965930
# 1               5.349086                                    4.113000
# 2               0.970217                                    4.646034
# 3               8.544945                                    4.615664
# 4               6.873486                                    4.558603
#
#    Food Production Index (2004-2006 = 100)  \
# 0                               110.395000
# 1                               116.470000
# ...

# %%
df2.to_csv('World_Bank_top30percentile_indicators_by_region.csv')
