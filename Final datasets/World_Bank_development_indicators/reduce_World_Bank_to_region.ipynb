# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/thuyt/Documents/GitHub/Anti-Corruption/Final datasets/World_Bank_development_indicators/COUNTRY LEVEL/wdi_country_top30.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country Code  Year Country Name  Corruption Perception Index  \
# 0           0          AFG  2005  Afghanistan                          NaN
# 1           1          AFG  2006  Afghanistan                          NaN
# 2           2          AFG  2007  Afghanistan                         18.0
# 3           3          AFG  2008  Afghanistan                         15.0
# 4           4          AFG  2009  Afghanistan                         13.0
#
#   IncomeGroup                  region_USAID region_WorldBank  \
# 0  Low income  South and Central Asia (SCA)       South Asia
# 1  Low income  South and Central Asia (SCA)       South Asia
# 2  Low income  South and Central Asia (SCA)       South Asia
# 3  Low income  South and Central Asia (SCA)       South Asia
# 4  Low income  South and Central Asia (SCA)       South Asia
#
#    Gni Growth (Annual %)  \
# 0               5.550398
# 1               5.694772
# 2               5.786177
# 3               5.025873
# ...

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df2 = df.groupby(['region_USAID', 'Year']).mean()

# %%
df2.head()
# Out:
#                                   Corruption Perception Index  \
# region_USAID                Year
# East Asia and Pacific (EAP) 2005                          NaN
#                             2006                          NaN
#                             2007                       25.250
#                             2008                       25.125
#                             2009                       25.250
#
#                                   Gni Growth (Annual %)  \
# region_USAID                Year
# East Asia and Pacific (EAP) 2005               8.230878
#                             2006              11.144238
#                             2007              11.279034
#                             2008              10.824226
#                             2009              -0.673745
#
#                                   Claims On Central Government (Annual Growth As % Of Broad Money)  \
# region_USAID                Year
# ...

# %%
df2 = df2.reset_index()

# %%
df2.head()
# Out:
#                   region_USAID  Year  Corruption Perception Index  \
# 0  East Asia and Pacific (EAP)  2005                          NaN
# 1  East Asia and Pacific (EAP)  2006                          NaN
# 2  East Asia and Pacific (EAP)  2007                       25.250
# 3  East Asia and Pacific (EAP)  2008                       25.125
# 4  East Asia and Pacific (EAP)  2009                       25.250
#
#    Gni Growth (Annual %)  \
# 0               8.230878
# 1              11.144238
# 2              11.279034
# 3              10.824226
# 4              -0.673745
#
#    Claims On Central Government (Annual Growth As % Of Broad Money)  \
# 0                                           4.835282
# 1                                           5.859510
# 2                                         -20.801226
# 3                                          -2.291178
# 4                                           3.000025
#
#    Claims On Private Sector (Annual Growth As % Of Broad Money)  \
# ...

# %%
df2.to_csv('World_Bank_top30percentile_indicators_by_region.csv')
