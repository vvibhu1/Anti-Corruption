# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
org = pd.read_csv('USAID_Anticorruption_Projects_Database.csv')

# %%
desc_sent = pd.read_csv('proj_desc_sentiment_Jen1.csv')

# %%
res_sent = pd.read_csv('proj_res_sentiment_Jen1.csv')

# %%
topic_model = pd.read_csv('df_document_topic.csv')

# %%
org.head()
# Out:
#    uuid                        region      country  \
# 0     1  South and Central Asia (SCA)  Afghanistan
# 1     2  South and Central Asia (SCA)  Afghanistan
# 2     3  South and Central Asia (SCA)  Afghanistan
# 3     4  South and Central Asia (SCA)  Afghanistan
# 4    30      Europe and Eurasia (E&E)      Albania
#
#                                              proj_nm  st_date end_date  \
# 0  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1  Rule of Law Stabilization Program - Formal Com...     2010     2012
# 2  Afghanistan Rule of Law Stabilization Project ...     2011     2012
# 3                         Political Party Assessment     2012     2012
# 4        Justice Sector Strengthening Project (JuST)     2010     2015
#
#        awd_amount awd_value                             implementer  \
# 0  e) $25 M-$50 M  26642989  Management Systems International (MSI)
# 1  e) $25 M-$50 M  33700000                           TetraTech ARD
# ...

# %%
data_frames = [org, desc_sent, res_sent]

# %%
df_merged = org.merge(topic_model, how='outer', left_index=True, right_index=True)

# %%
df_merged.head()
# Out:
#    uuid                        region      country  \
# 0     1  South and Central Asia (SCA)  Afghanistan
# 1     2  South and Central Asia (SCA)  Afghanistan
# 2     3  South and Central Asia (SCA)  Afghanistan
# 3     4  South and Central Asia (SCA)  Afghanistan
# 4    30      Europe and Eurasia (E&E)      Albania
#
#                                              proj_nm  st_date end_date  \
# 0  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1  Rule of Law Stabilization Program - Formal Com...     2010     2012
# 2  Afghanistan Rule of Law Stabilization Project ...     2011     2012
# 3                         Political Party Assessment     2012     2012
# 4        Justice Sector Strengthening Project (JuST)     2010     2015
#
#        awd_amount awd_value                             implementer  \
# 0  e) $25 M-$50 M  26642989  Management Systems International (MSI)
# 1  e) $25 M-$50 M  33700000                           TetraTech ARD
# ...

# %%
df_merged2 = df_merged.merge(desc_sent, how='outer', left_index=True, right_index=True)

# %%
df_merged2.columns
# Out:
# Index(['uuid_x', 'region', 'country', 'proj_nm', 'st_date', 'end_date',
#        'awd_amount', 'awd_value', 'implementer', 'sector', 'intervention',
#        'intervention_type', 'proj_desc_x', 'proj_res', 'rfp_rftop',
#        'final_res', 'mind_eval', 'final_eval', 'audit', 'interim_rep',
#        'addl_docs', 'addl_info', 'corruption', 'stability', 'Unnamed: 0_x',
#        'Topic0', 'Topic1', 'Topic2', 'Topic3', 'Topic4', 'dominant_topic',
#        'Unnamed: 0_y', 'uuid_y', 'proj_desc_y', 'desc_polarity',
#        'desc_subjectivity', 'desc_polarity_label', 'desc_subjectivity_label'],
#       dtype='object')
