# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
cd /Users/yanglingxi/Documents/GitHub/Anti-Corruption/Final datasets/USAID/country-level datasets
# Out:
# /Users/yanglingxi/Documents/GitHub/Anti-Corruption/Final datasets/USAID/country-level datasets

# %%
# country_level_xiang_and_lingxi.csv dataset
df1 = pd.read_csv('country_level_xiang_and_lingxi.csv')
df1.sort_values('country', ascending=True,inplace=True)
df1.drop(columns = 'Unnamed: 0', inplace = True)
df1.head(5)
# Out:
#        country  duration_mean  duration_min  duration_max  duration_median  \
# 0  Afghanistan       3.071429             0             7              3.0
# 1      Albania       3.750000             2             5              3.5
# 2       Angola       5.000000             5             5              5.0
# 3      Armenia       4.250000             4             5              4.0
# 4   Azerbaijan       2.800000             1             4              3.0
#
#    topic0_mean  topic0_min  topic0_max  topic0_median  topic1_mean  ...  \
# 0     0.036429        0.03        0.06          0.030     0.037857  ...
# 1     0.037500        0.03        0.05          0.040     0.078750  ...
# 2     0.030000        0.03        0.03          0.030     0.030000  ...
# 3     0.035000        0.03        0.04          0.035     0.035000  ...
# 4     0.032000        0.03        0.04          0.030     0.032000  ...
#
#    Governance_count  Healthcare_count  Public_Finance_count  \
# ...

# %%
# country_level_Jen.csv' dataset
df2 = pd.read_csv('country_level_Jen.csv')
df2.sort_values('country', ascending=True,inplace=True)
df2.drop(columns = 'country', inplace = True)
df2.head(5)
# Out:
#    desc_senti_score_median  desc_sub_score_median  res_senti_score_median  \
# 0                 0.000000               0.200000                0.007407
# 1                 0.025000               0.421111               -0.055508
# 2                 0.140625               0.219792               -0.188889
# 3                -0.103125               0.310417                0.000000
# 4                -0.015625               0.463750                0.000000
#
#    res_sub_score_median  desc_senti_score_mean  desc_sub_score_mean  \
# 0              0.442262               0.002660             0.250124
# 1              0.291667               0.053542             0.411111
# 2              0.320833               0.140625             0.219792
# 3              0.347470              -0.108705             0.348065
# 4              0.314892               0.021792             0.342333
#
#    res_senti_score_mean  res_sub_score_mean  desc_senti_score_min  \
# ...

# %%
# country_level_Yue.csvdataset
df3 = pd.read_csv('country_level_Yue.csv')
df3.sort_values('country', ascending=True,inplace=True)
df3.drop(columns = 'country', inplace = True)
df3.head(5)
# Out:
#    awd_value_min  awd_value_max  awd_value_mean  awd_value_median  \
# 0      1635357.0    349078330.0    6.950936e+07        49100468.0
# 1      5100000.0     15731000.0    9.396956e+06         8809162.5
# 2     16900000.0     16900000.0    1.690000e+07        16900000.0
# 3       548000.0     15500000.0    8.619596e+06         9810789.0
# 4       800000.0     12029205.0    5.832565e+06         5250528.0
#
#    awd_amount_very_low  awd_amount_low  awd_amount_median_low  \
# 0                    4               1                      3
# 1                    0               0                      6
# 2                    0               0                      0
# 3                    1               0                      1
# 4                    1               1                      1
#
#    awd_amount_median  awd_amount_median_high  awd_amount_high  \
# 0                  1                       7                7
# 1                  2                       0                0
# ...

# %%
df = pd.concat([df1,df2,df3], axis=1)
df
# Out:
#                country  duration_mean  duration_min  duration_max  \
# 0          Afghanistan       3.071429             0             7
# 1              Albania       3.750000             2             5
# 2               Angola       5.000000             5             5
# 3              Armenia       4.250000             4             5
# 4           Azerbaijan       2.800000             1             4
# ..                 ...            ...           ...           ...
# 69             Ukraine       3.375000             2             5
# 70             Vietnam       3.500000             3             4
# 71  West Bank and Gaza       4.200000             2             6
# 72               Yemen       4.000000             3             5
# 73              Zambia       2.500000             2             3
#
#     duration_median  topic0_mean  topic0_min  topic0_max  topic0_median  \
# 0               3.0     0.036429        0.03        0.06          0.030
# ...

# %%
df.to_csv('combined_usaid_country_Nov_23.csv')
