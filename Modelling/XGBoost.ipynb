# %%
import pandas as pd

df = pd.read_csv('final.csv')
pd.DataFrame(df.isna().sum()*100/df.shape[0]).plot.bar(figsize=(20,5))
df = df.dropna()

# %%
## Researving this column for the end
df_RWB = df['region_WorldBank']

# dropping unnecessary columns
df.drop(['Unnamed: 0', 'Unnamed: 0.1','region_WorldBank','Country Code'],axis=1,inplace=True)
df.dropna()
# Out:
#       Index  Year Country Name  Corruption Perception Index  \
# 56      196  2007  Afghanistan                         18.0
# 57      197  2007  Afghanistan                         18.0
# 58      198  2007  Afghanistan                         18.0
# 59      199  2007  Afghanistan                         18.0
# 60      200  2007  Afghanistan                         18.0
# ...     ...   ...          ...                          ...
# 4019   5359  2017       Zambia                         37.0
# 4020   5360  2018       Zambia                         35.0
# 4021   5361  2018       Zambia                         35.0
# 4022   5362  2019       Zambia                         34.0
# 4023   5363  2019       Zambia                         34.0
#
#               IncomeGroup                  region_USAID  \
# 56             Low income  South and Central Asia (SCA)
# 57             Low income  South and Central Asia (SCA)
# 58             Low income  South and Central Asia (SCA)
# 59             Low income  South and Central Asia (SCA)
# 60             Low income  South and Central Asia (SCA)
# ...                   ...                           ...
# 4019  Lower middle income      Sub-Saharan Africa (SSA)
# 4020  Lower middle income      Sub-Saharan Africa (SSA)
# 4021  Lower middle income      Sub-Saharan Africa (SSA)
# 4022  Lower middle income      Sub-Saharan Africa (SSA)
# 4023  Lower middle income      Sub-Saharan Africa (SSA)
#
#       Access To Electricity, Rural (% Of Rural Population)  \
# 56                                            19.868266
# 57                                            19.868266
# 58                                            19.868266
# 59                                            19.868266
# 60                                            19.868266
# ...                                                 ...
# 4019                                          13.997699
# 4020                                          10.968000
# 4021                                          10.968000
# 4022                                          13.775150
# 4023                                          13.775150
#
#       Food Production Index (2004-2006 = 100)  \
# 56                                  108.92000
# 57                                  108.92000
# 58                                  108.92000
# 59                                  108.92000
# 60                                  108.92000
# ...                                       ...
# 4019                                171.55394
# 4020                                156.42136
# 4021                                156.42136
# 4022                                153.82510
# 4023                                153.82510
#
#       Agricultural Land (% Of Land Area)  \
# 56                             58.067580
# 57                             58.067580
# 58                             58.067580
# 59                             58.067580
# 60                             58.067580
# ...                                  ...
# 4019                           32.476466
# 4020                           33.127447
# 4021                           33.127447
# 4022                           34.782422
# 4023                           34.782422
#
#       Urban Population (% Of Total Population)  ...  \
# 56                                      23.113  ...
# 57                                      23.113  ...
# 58                                      23.113  ...
# 59                                      23.113  ...
# 60                                      23.113  ...
# ...                                        ...  ...
# 4019                                    42.976  ...
# 4020                                    43.521  ...
# 4021                                    43.521  ...
# 4022                                    44.072  ...
# 4023                                    44.072  ...
#
#       Population Ages 0-14 (% Of Total Population)  \
# 56                                       48.126233
# 57                                       48.126233
# 58                                       48.126233
# 59                                       48.126233
# 60                                       48.126233
# ...                                            ...
# 4019                                     45.411369
# 4020                                     44.936141
# 4021                                     44.936141
# 4022                                     44.462509
# 4023                                     44.462509
#
#       Access To Clean Fuels And Technologies For Cooking (% Of Population)  \
# 56                                             15.99000
# 57                                             15.99000
# 58                                             15.99000
# 59                                             15.99000
# 60                                             15.99000
# ...                                                 ...
# 4019                                           16.75112
# 4020                                           16.58418
# 4021                                           16.58418
# 4022                                           17.74318
# 4023                                           17.74318
#
#       People Using At Least Basic Drinking Water Services, Rural (% Of Rural Population)  \
# 56                                            33.732741
# 57                                            33.732741
# 58                                            33.732741
# 59                                            33.732741
# 60                                            33.732741
# ...                                                 ...
# 4019                                          41.952058
# 4020                                          44.134510
# 4021                                          44.134510
# 4022                                          45.556623
# 4023                                          45.556623
#
#       People Using At Least Basic Sanitation Services, Rural (% Of Rural Population)  \
# 56                                            27.476086
# 57                                            27.476086
# 58                                            27.476086
# 59                                            27.476086
# 60                                            27.476086
# ...                                                 ...
# 4019                                          18.932012
# 4020                                          18.919180
# 4021                                          18.919180
# 4022                                          18.179606
# 4023                                          18.179606
#
#       Labor Force Participation Rate, Total (% Of Total Population Ages 15-64) (Modeled Ilo Estimate)  \
# 56                                            49.344002
# 57                                            49.344002
# 58                                            49.344002
# 59                                            49.344002
# 60                                            49.344002
# ...                                                 ...
# 4019                                          75.505997
# 4020                                          75.313004
# 4021                                          75.313004
# 4022                                          75.259003
# 4023                                          75.259003
#
#       Unemployment, Total (% Of Total Labor Force) (Modeled Ilo Estimate)  \
# 56                                               11.046
# 57                                               11.046
# 58                                               11.046
# 59                                               11.046
# 60                                               11.046
# ...                                                 ...
# 4019                                             11.626
# 4020                                             11.500
# 4021                                             11.500
# 4022                                             11.425
# 4023                                             11.425
#
#       Gdp Per Person Employed (Constant 2017 Ppp $)  \
# 56                                      7056.174167
# 57                                      7056.174167
# 58                                      7056.174167
# 59                                      7056.174167
# 60                                      7056.174167
# ...                                             ...
# 4019                                    9648.782217
# 4020                                    9676.891123
# 4021                                    9676.891123
# 4022                                    9479.540064
# 4023                                    9479.540064
#
#       Wage And Salaried Workers, Total (% Of Total Employment) (Modeled Ilo Estimate)  \
# 56                                             8.852000
# 57                                             8.852000
# 58                                             8.852000
# 59                                             8.852000
# 60                                             8.852000
# ...                                                 ...
# 4019                                          21.349001
# 4020                                          21.507000
# 4021                                          21.507000
# 4022                                          21.563000
# 4023                                          21.563000
#
#       Import Volume Index (2000 = 100)  Trade (% Of Gdp)
# 56                          187.697479         55.393618
# 57                          187.697479         55.393618
# 58                          187.697479         55.393618
# 59                          187.697479         55.393618
# 60                          187.697479         55.393618
# ...                                ...               ...
# 4019                        567.892902         71.585759
# 4020                        626.417589         72.966216
# 4021                        626.417589         72.966216
# 4022                        344.359603         70.035035
# 4023                        344.359603         70.035035
#
# [3248 rows x 68 columns]

# %%
#### PRE PROCESSING ###

# %%
from sklearn import preprocessing
# label_encoder object knows how to understand word labels, we will only do it for columns where we see a level, it is in order  
label_encoder = preprocessing.LabelEncoder()
df['IncomeGroup']= label_encoder.fit_transform(df['IncomeGroup'])

# %%
#Categorical Columns

object_type = df.select_dtypes(include=['object']).columns.to_list()
print(object_type)
# Out:
# ['Country Name', 'region_USAID']

# %%
## Seperating the data. 

y = df[['Corruption Perception Index']]
X = df.drop(['Corruption Perception Index','Index'],axis=1, inplace = True)

#one hot encoding the coulmns 
X = pd.get_dummies(df)


# SCALING THE DATA
#we will see if this helps in the end
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
#drop region world bank when doing modelling and don't use index
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Model Fitting

from xgboost import XGBClassifier

# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# /Users/yanglingxi/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# XGBClassifier(objective='multi:softprob')

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, predictions)
# Out:
# 0.42

# %%
# plot feature importance
from xgboost import plot_importance
plot_importance(model, max_num_features=25)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
plot_importance(model, max_num_features=30)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
