# %%
import pandas as pd
import numpy as np

# %%
df5 = pd.read_csv("WDIData.csv")
df5.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013      2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN   NaN   NaN
# ...

# %%
df5['Indicator Code'].unique()
# Out:
# array(['EG.CFT.ACCS.ZS', 'EG.ELC.ACCS.ZS', 'EG.ELC.ACCS.RU.ZS', ...,
#        'SP.M15.2024.FE.ZS', 'SP.M18.2024.FE.ZS', 'SH.DYN.AIDS.FE.ZS'],
#       dtype=object)

# %%
df5['Indicator Code'].nunique()
# Out:
# 1437

# %%
df5.shape
# Out:
# (379368, 66)

# %%
yr_list = ['2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019',]
df6 = df5.melt(id_vars =['Indicator Code','Country Name'], value_vars = yr_list, var_name ='Year', value_name ='Value') 
df6.head(20)
# Out:
#               Indicator Code Country Name  Year     Value
# 0             EG.CFT.ACCS.ZS   Arab World  2007       NaN
# 1             EG.ELC.ACCS.ZS   Arab World  2007       NaN
# 2          EG.ELC.ACCS.RU.ZS   Arab World  2007       NaN
# 3          EG.ELC.ACCS.UR.ZS   Arab World  2007       NaN
# 4             FX.OWN.TOTL.ZS   Arab World  2007       NaN
# 5          FX.OWN.TOTL.FE.ZS   Arab World  2007       NaN
# 6          FX.OWN.TOTL.MA.ZS   Arab World  2007       NaN
# 7          FX.OWN.TOTL.OL.ZS   Arab World  2007       NaN
# 8          FX.OWN.TOTL.40.ZS   Arab World  2007       NaN
# 9          FX.OWN.TOTL.PL.ZS   Arab World  2007       NaN
# 10         FX.OWN.TOTL.60.ZS   Arab World  2007       NaN
# 11         FX.OWN.TOTL.SO.ZS   Arab World  2007       NaN
# 12         FX.OWN.TOTL.YG.ZS   Arab World  2007       NaN
# 13  per_si_allsi.adq_pop_tot   Arab World  2007       NaN
# 14     per_allsp.adq_pop_tot   Arab World  2007       NaN
# ...

# %%
df6.shape
# Out:
# (4931784, 4)

# %%
df3 = pd.read_csv("USAID_Anticorruption_Projects_Database.csv")
df3.head()
# Out:
#    uuid                        region      country  \
# 0     1  South and Central Asia (SCA)  Afghanistan
# 1     2  South and Central Asia (SCA)  Afghanistan
# 2     3  South and Central Asia (SCA)  Afghanistan
# 3     4  South and Central Asia (SCA)  Afghanistan
# 4    30      Europe and Eurasia (E&E)      Albania
#
#                                              proj_nm  st_date end_date  \
# 0  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1  Rule of Law Stabilization Program - Formal Com...     2010     2012
# 2  Afghanistan Rule of Law Stabilization Project ...     2011     2012
# 3                         Political Party Assessment     2012     2012
# 4        Justice Sector Strengthening Project (JuST)     2010     2015
#
#        awd_amount awd_value                             implementer  \
# 0  e) $25 M-$50 M  26642989  Management Systems International (MSI)
# 1  e) $25 M-$50 M  33700000                           TetraTech ARD
# ...

# %%
df3.shape
# Out:
# (315, 24)

# %%
df4 = df3.merge(df6, how='left',left_on=['end_date','country'], right_on=['Year','Country Name'])
df4.head()
# Out:
#    uuid                        region      country  \
# 0     1  South and Central Asia (SCA)  Afghanistan
# 1     1  South and Central Asia (SCA)  Afghanistan
# 2     1  South and Central Asia (SCA)  Afghanistan
# 3     1  South and Central Asia (SCA)  Afghanistan
# 4     1  South and Central Asia (SCA)  Afghanistan
#
#                                              proj_nm  st_date end_date  \
# 0  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 1  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 2  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 3  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
# 4  Assistance for Afghanistan's Anti-Corruption A...     2010     2013
#
#        awd_amount awd_value                             implementer  \
# 0  e) $25 M-$50 M  26642989  Management Systems International (MSI)
# 1  e) $25 M-$50 M  26642989  Management Systems International (MSI)
# ...

# %%
df4.shape
# Out:
# (379419, 28)
