# %%
import pandas as pd
import numpy as np

# %%
s0 = pd.read_csv('Step0_Ind_country_Yue.csv')
s0.head()
# Out:
#    Unnamed: 0 Country Name Country Code  \
# 0           0  Afghanistan          AFG
# 1           1  Afghanistan          AFG
# 2           2  Afghanistan          AFG
# 3           3  Afghanistan          AFG
# 4           4  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access To Clean Fuels And Technologies For Coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access To Electricity (% Of Population)     EG.ELC.ACCS.ZS   NaN
# 2  Access To Electricity, Rural (% Of Rural Popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access To Electricity, Urban (% Of Urban Popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account Ownership At A Financial Institution O...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  ...       2013       2014       2015      2016  \
# 0   NaN   NaN   NaN   NaN  ...  26.170000  27.990000  30.100000  32.44000
# 1   NaN   NaN   NaN   NaN  ...  68.933266  89.500000  71.500000  97.70000
# ...

# %%
s4 = pd.read_csv('Step4_merge_USAID_region_Jen.csv')
s4.head()
# Out:
#    Unnamed: 0 Country Code  Year Country Name  \
# 0           0          AFG  2000  Afghanistan
# 1           1          AFG  2000  Afghanistan
# 2           2          AFG  2000  Afghanistan
# 3           3          AFG  2000  Afghanistan
# 4           4          AFG  2000  Afghanistan
#
#    Access To Clean Fuels And Technologies For Cooking (% Of Population)  \
# 0                                                8.8
# 1                                                8.8
# 2                                                8.8
# 3                                                8.8
# 4                                                8.8
#
#    Access To Electricity (% Of Population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Access To Electricity, Rural (% Of Rural Population)  \
# ...

# %%
s5 = s0[['Country Code','Region', 'IncomeGroup']]
#final = pd.merge(s5, s4, how = 'right', on = 'Country Code')
#final.head()

# %%
s5.drop_duplicates(inplace = True)
s5.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Country Code                      Region          IncomeGroup
# 0             AFG                  South Asia           Low income
# 1437          ALB       Europe & Central Asia  Upper middle income
# 2874          DZA  Middle East & North Africa  Lower middle income
# 4311          ASM         East Asia & Pacific  Upper middle income
# 5748          AND       Europe & Central Asia          High income

# %%
s5.shape
# Out:
# (217, 3)

# %%
final = s4.merge(s5, how = 'left', on = 'Country Code')
final.head()
# Out:
#    Unnamed: 0 Country Code  Year Country Name  \
# 0           0          AFG  2000  Afghanistan
# 1           1          AFG  2000  Afghanistan
# 2           2          AFG  2000  Afghanistan
# 3           3          AFG  2000  Afghanistan
# 4           4          AFG  2000  Afghanistan
#
#    Access To Clean Fuels And Technologies For Cooking (% Of Population)  \
# 0                                                8.8
# 1                                                8.8
# 2                                                8.8
# 3                                                8.8
# 4                                                8.8
#
#    Access To Electricity (% Of Population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Access To Electricity, Rural (% Of Rural Population)  \
# ...

# %%
final.drop('Unnamed: 0', axis = 1, inplace = True)
#inal['region'] = final['region_USAID']
#inal['Region'] = final['region_WorldBank']
#inal.drop(['Region','region'], axis = 1, inplace = True)
#inal.head()

# %%
final['region_USAID'] = final['region']
final['region_WorldBank'] = final['Region']

# %%
final.drop(['region', 'Region'], axis = 1, inplace = True)
final.head()
# Out:
#   Country Code  Year Country Name  \
# 0          AFG  2000  Afghanistan
# 1          AFG  2000  Afghanistan
# 2          AFG  2000  Afghanistan
# 3          AFG  2000  Afghanistan
# 4          AFG  2000  Afghanistan
#
#    Access To Clean Fuels And Technologies For Cooking (% Of Population)  \
# 0                                                8.8
# 1                                                8.8
# 2                                                8.8
# 3                                                8.8
# 4                                                8.8
#
#    Access To Electricity (% Of Population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Access To Electricity, Rural (% Of Rural Population)  \
# 0                                                NaN
# ...

# %%
final.to_csv('final.csv')
